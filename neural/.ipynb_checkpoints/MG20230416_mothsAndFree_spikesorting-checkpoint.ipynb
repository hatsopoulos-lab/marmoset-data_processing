# %% [markdown]
# ## Spike Processing Pipeline ver 0.2
# This notebook specifes a preprocessing pipeline for neural data colleted on blackrock aquisition devices in the Hatsopoulos lab. The file assumes that spikeinterface(ver 0.13 - 0.10), python-neo, matplotlib, numpy, PHY, and pandas are installed.
#
# The code needs a datafile (ns6) and a probe file (you can find tony's its at /Paul/prbfiles/TY_array.prb). This script will automatically precondition the data (filtering and referencing), attach probe infomation (via .prb file) and pull out LFP data. The file will then sort the neural data with a number of different sorters, and comparitive sort to find the units common to all of the sorters (see https://elifesciences.org/articles/61834 ). Finally, it will convert the automatic sorting of one sorter (It is recommened to use IronClust as your primary sorter) and mark the common units as 'good' in the phy output.
#
# The user would then mark each cluster as good (SU), MUA (multiunit), or noise. For analysis, you could read the phy output directly (numpy files) or you could inmport back to spikeinterface and save.
#
# Useful web sites:
# spikeinterface docs (for old api): https://spikeinterface.readthedocs.io/en/0.13.0/
# phy docs: https://phy.readthedocs.io/en/latest/
# Useful info about .prb files): https://tridesclous.readthedocs.io/en/latest/important_details.html
#                                https://spyking-circus.readthedocs.io/en/latest/code/probe.html

# %% [markdown]
# ## preprocessing MG20230416_1505_mothsAndFree-002

# %%
# import the necessary toolboxes. Note unknown installation problem with matplotlib. Run this cell 2x. Will complain
# but ok.

import matplotlib.pyplot as plt
import spikeinterface
import spikeinterface.extractors as se 
import spikeinterface.toolkit as st
import spikeinterface.sorters as ss
import spikeinterface.comparison as sc
import spikeinterface.widgets as sw
import numpy as np
import pandas as pd
from os.path import join as pjoin
import os
import glob
import pynwb

# specify inline plotting
# %matplotlib notebook
#plt.switch_backend('Qt5Agg')

# %%
# User defined information about the data

pth = '/project/nicho/data/marmosets/electrophys_data_for_processing' # path to data directory
sess = 'MG20230416_1505_mothsAndFree' # directory where Ns6 file lives
file = 'MG20230416_1505_mothsAndFree-002.ns6' # name of NS6 file
prbfile = '/project/nicho/data/marmosets/prbfiles/MG_01_integer.prb' # name of probe (.prb) file

# User defined paths to sorters
sorters_dir    = '/project/nicho/environments/matlabtools'
kilosort_path  = pjoin(sorters_dir, 'Kilosort-2.5/')
ironclust_path = pjoin(sorters_dir, 'ironclust/')
waveclus_path  = pjoin(sorters_dir, 'wave_clus/')

# %% [markdown]
# ## Run the next cell to reload a recording that has already been prepared for spikesorting

# %%
# load up from save: If you need to reload the data above, you can just run this cell
try:
    recording_cache = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/recording.pkl'))
    # check the channel properties are correct
    recording_cache.get_shared_channel_property_names()
    
    print('Skip subsequent steps until you reach the "Spike Sorting" header')

except:
    print('The processed recording does not exist at %s.\n\n Continue on to "Load Unprocessed Data" and "Preprocessing" sections' % pjoin(pth, sess, 'processed/recording.pkl'))
# Out:
# Skip subsequent steps until you reach the "Spike Sorting" header

# %% [markdown]
# ## Load Unprocessed Data

# %%
def load_recording_and_prbfile(recording_folder, prbfile):
    # load recording
    recording = se.BlackrockRecordingExtractor(recording_folder, nsx_to_load=6)
    # load probe information
    recording_prb = recording.load_probe_file(prbfile)
    
    return recording_prb

# %%
# Load recording and probefile
recording_folder = pjoin(pth, sess, file)
print('recording_folder: ', recording_folder)
print('probefile: ', prbfile)

recording_prb = load_recording_and_prbfile(recording_folder, prbfile)

# check that info correct properties are present (should be gain, group, location, name, and offset)
recording_prb.get_shared_channel_property_names()
# Out:
# recording_folder:  /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/MG20230416_1505_mothsAndFree-002.ns6
# probefile:  /project/nicho/data/marmosets/prbfiles/MG_01_integer.prb
# ['gain', 'group', 'impedance', 'location', 'name', 'offset']

# %%
# visualize probe geometry: want to see that it looks correct
w_elec = sw.plot_electrode_geometry(recording_prb)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## Preprocessing
# First step is common median filtering (the median across all channels is removed sample wise from the signal at each probe). Then the signal at each channel is low pass filtered and saved off as the lfp. The data is then bandpass filtered for spike processing. The filter values can be set, the defaults are 350Hz for LFP and 350-7500Hz for spikes. Some plots to review the data and save progress. The spike data is saved as a cache. All of the filtering is only done when the data is read. So to save time in future steps, we save the filtered/processed data to file.

# %%
# automagically attempt top find bad channels. need to then specify them in next cell by 
# editing channels_to_remove. Enter exactly the list that is printed here (output in base-0, enter in base-0).
st.preprocessing.remove_bad_channels(recording_prb, verbose=True)
print('(Channels not actually removed. Edit "channels_to_remove = []" in the next cell to match this output)')
# Out:
# Automatically removing channels: [15, 66, 68]
# (Channels not actually removed. Edit "channels_to_remove = []" in the next cell to match this output)

# %%
# Specify any channels to remove: Default list of channels_to_remove should be empty.

channels_to_remove = [] #[15, 66, 68]

# %%
# defining next few steps within a function so intermediate recording_ variables don't hold on to RAM
def process_raw_recording(recording_prb, channels_to_remove):
    
    # condition the signal for the lfp
    # lowpass filter for lfp
    recording_lp = st.preprocessing.bandpass_filter(recording_prb, freq_min=1, freq_max=350, filter_type='butter')
    # downsample
    recording_lfp = st.preprocessing.resample(recording_lp, resample_rate=1000)
    
    # remove bad channels or set recording_rmc to unaltered recording_prb
    if len(channels_to_remove) > 0:
        channels_to_remove = [ch+1 for ch in channels_to_remove]
        recording_rmc = st.preprocessing.remove_bad_channels(recording_prb, bad_channel_ids=channels_to_remove)
    else:
        recording_rmc = recording_prb

    # verify that all of the properties were trnasfered to the new recording object
    print('properties: ', recording_rmc.get_shared_channel_property_names())
    # verify bad channels have been removed
    print('ids: ', recording_rmc.get_channel_ids())    
    
    # bandpass filter for spikes, then common median reference
    recording_f = st.preprocessing.bandpass_filter(recording_rmc, freq_min=350, freq_max=7500, filter_type='butter')
    recording_cmr = st.preprocessing.common_reference(recording_f, reference='median')
    
    return recording_lfp, recording_cmr

# %%
recording_lfp, recording_cmr = process_raw_recording(recording_prb, channels_to_remove)
# Out:
# properties:  ['gain', 'group', 'impedance', 'location', 'name', 'offset']
# ids:  [49, 33, 50, 34, 51, 35, 52, 36, 53, 37, 54, 38, 55, 39, 56, 40, 57, 41, 58, 42, 59, 43, 60, 44, 61, 45, 62, 46, 63, 47, 64, 48, 17, 1, 18, 2, 19, 3, 20, 4, 21, 5, 22, 6, 23, 7, 24, 8, 25, 9, 26, 10, 27, 11, 28, 12, 29, 13, 30, 14, 31, 15, 32, 16, 81, 65, 82, 66, 83, 67, 84, 68, 85, 69, 86, 70, 87, 71, 88, 72, 89, 73, 90, 74, 91, 75, 92, 76, 93, 77, 94, 78, 95, 79, 96, 80]

# %%
# view the signal on channels. channel_id is the probe and trange is the time sample to view in seconds
sw.plot_timeseries(recording_cmr, channel_ids=[2, 5, 7], trange=[0, 6])
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
# view the power spectrum of the data. Check that the filtering looks reasonable. You can also look at the
# the raw data: recording, or the lfp: recording_lfp, or the spike data: recording_f
w_sp = sw.plot_spectrum(recording_prb, channels=[5])
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
# save preprocessed data for spikes and cache recording
recording_cache = se.CacheRecordingExtractor(recording_cmr, save_path=pjoin(pth, sess, 'processed/filtered_data.dat'))
recording_cache.dump_to_dict()
print('finished saving %s' % pjoin(pth, sess, 'processed/filtered_data.dat'))
recording_cache.dump_to_pickle(pjoin(pth, sess, 'processed/recording.pkl'))
print('finished saving %s' % pjoin(pth, sess, 'processed/recording.pkl'))
# save preprocessed data for lfp
se.CacheRecordingExtractor(recording_lfp, save_path=pjoin(pth, sess, 'processed/lfp_data.dat'))
print('finished saving %s' % pjoin(pth, sess, 'processed/lfp_data.dat'))
# Out:
# finished saving /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/filtered_data.dat
# finished saving /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/recording.pkl
# finished saving /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/lfp_data.dat

# %% [markdown]
# ## Spike Sorting
# First step is to set the parameters for the sorters. Then call each sorter that you want to run. Each run will make its own folder with the sorting results and save the results. You can also add aditional sorters. For example if you want to add YASS you can follow the pattern set here. See the documentation to install.

# %%
# set the paths for the sorters you want to run
ss.Kilosort2_5Sorter.set_kilosort2_5_path(kilosort_path)
ss.IronClustSorter.set_ironclust_path(ironclust_path)
ss.WaveClusSorter.set_waveclus_path(waveclus_path)
# Out:
# Setting KILOSORT2_5_PATH environment variable for subprocess calls to: /project/nicho/environments/matlabtools/Kilosort-2.5
# Setting IRONCLUST_PATH environment variable for subprocess calls to: /project/nicho/environments/matlabtools/ironclust
# Setting WAVECLUS_PATH environment variable for subprocess calls to: /project/nicho/environments/matlabtools/wave_clus

# %%
# check which sorters are installed
ss.installed_sorters()
# Out:
# ['ironclust',
#  'kilosort2_5',
#  'klusta',
#  'spykingcircus',
#  'tridesclous',
#  'waveclus']

# %% [markdown]
# ## Spyking Circus
# Spyking circus nicely complains when an electrode is too corrupted to sort, so run this first and check to see if there are any problem electrodes. You can find which channels didn't get sorted by searching the results, each probe has its own folder, so search: ls results_sc/?/recording/*result.hdf5.  If so, you can go back and exclude those probes from the analysis by inserting the problematic probe numbers into the previous cell for exluding probes (don't forget that the probes will be in python 0-based, and you need to specify in the cell above the probe number in 1-based system). When bad electrodes are found Spyking Circus will tell you in the log which probe it is, then it will crash just before it completes. You can find the bad probes becuase they will be missing a *recording.result.hdf5* file in that probes recording directory (for ex. for the first probe the file would be located at processed/results_sc/0/recording/). Once you get spyking circus to run through to completion, everything else should work no problem.

# %%
# Start with spyking circus. list the parameters for the sorter
ss.get_params_description('spykingcircus')
# Out:
# {'detect_sign': 'Use -1 (negative), 1 (positive) or 0 (both) depending on the sign of the spikes in the recording',
#  'adjacency_radius': 'Radius in um to build channel neighborhood',
#  'detect_threshold': 'Threshold for spike detection',
#  'template_width_ms': 'Template width in ms. Recommended values: 3 for in vivo - 5 for in vitro',
#  'filter': 'Enable or disable filter',
#  'merge_spikes': 'Enable or disable automatic mergind',
#  'auto_merge': 'Automatic merging threshold',
#  'num_workers': 'Number of workers (if None, half of the cpu number is used)',
#  'whitening_max_elts': 'Max number of events per electrode for whitening',
#  'clustering_max_elts': 'Max number of events per electrode for clustering'}

# %%
# see what the default parameters are. These are the only parameters spikeinterface will let you modify.
ss.get_default_params('spykingcircus')
# Out:
# {'detect_sign': -1,
#  'adjacency_radius': 100,
#  'detect_threshold': 6,
#  'template_width_ms': 3,
#  'filter': True,
#  'merge_spikes': True,
#  'auto_merge': 0.75,
#  'num_workers': None,
#  'whitening_max_elts': 1000,
#  'clustering_max_elts': 10000}

# %%
# set your own parameter values
params = {'detect_sign': -1,
 'adjacency_radius': 100,
 'detect_threshold': 6,
 'template_width_ms': 3,
 'filter': False,
 'merge_spikes': True,
 'auto_merge': 0.75,
 'num_workers': 1,
 'whitening_max_elts': 1000,
 'clustering_max_elts': 10000}

# %%
# run the sorter
sorting_SC = ss.run_spykingcircus(recording_cache, 
                                  output_folder=pjoin(pth, sess, 'processed/results_sc'), 
                                  grouping_property='group',
                                  n_jobs=1,
                                  verbose=True, 
                                  **params)
print(f'SpykingCircus found {len(sorting_SC.get_unit_ids())} units')

# find bad channels from spyking circus output
sc_channel_folders = glob.glob(pjoin(pth, sess, 'processed/results_sc', '*'))
bad_chans = []
for chfold in sc_channel_folders:
    good_chan = os.path.exists(pjoin(chfold, 'recording', 'recording.result.hdf5'))
    if not good_chan:
        bad_chans.append(int(os.path.basename(chfold)))
bad_chans = sorted(bad_chans)

print('bad_channels from spykingcircus are %s' % bad_chans)

# If no bad channels, save sorting results in case of crash
if len(bad_chans) == 0:
    sorting_SC.dump_to_dict()
    sorting_SC.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_sc.pkl'))

# %% [markdown]
# ##### To Reload SpykingCircus sort from pkl (uncomment and run next cell)

# %%
sorting_SC = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/sorting_sc.pkl'))

# %% [markdown]
# ## Ironclust

# %%
# ironclust tends to do ok for our arrays same procedure view available paramters
ss.get_params_description('ironclust')
# Out:
# {'detect_sign': 'Use -1 (negative), 1 (positive) or 0 (both) depending on the sign of the spikes in the recording',
#  'adjacency_radius': 'Use -1 to include all channels in every neighborhood',
#  'adjacency_radius_out': 'Use -1 to include all channels in every neighborhood',
#  'detect_threshold': 'detection threshold',
#  'prm_template_name': '.prm template file name',
#  'freq_min': 'High-pass filter cutoff frequency',
#  'freq_max': 'Low-pass filter cutoff frequency',
#  'merge_thresh': 'Threshold for automated merging',
#  'pc_per_chan': 'Number of principal components per channel',
#  'whiten': 'Whether to do channel whitening as part of preprocessing',
#  'filter_type': 'Filter type: none, bandpass, wiener, fftdiff, ndiff',
#  'filter_detect_type': 'Filter type for detection: none, bandpass, wiener, fftdiff, ndiff',
#  'common_ref_type': 'Common reference type: none, mean, median, trimmean',
#  'batch_sec_drift': 'Batch duration in seconds. clustering time duration',
#  'step_sec_drift': 'Compute anatomical similarity every n sec',
#  'knn': 'K nearest neighbors',
#  'min_count': 'Minimum cluster size',
#  'fGpu': 'Use GPU if True',
#  'fft_thresh': 'FFT-based noise peak threshold',
#  'fft_thresh_low': 'FFT-based noise peak lower threshold (set to 0 to disable dual thresholding scheme)',
#  'nSites_whiten': 'Number of adjacent channels to whiten',
#  'feature_type': 'gpca, pca, vpp, vmin, vminmax, cov, energy, xcov',
#  'delta_cut': 'Cluster detection threshold (delta-cutoff)',
#  'post_merge_mode': 'Post merge mode',
#  'sort_mode': 'Sort mode',
#  'fParfor': 'Parfor loop',
#  'filter': 'Enable or disable filter',
#  'clip_pre': 'Pre-peak clip duration in ms',
#  'clip_post': 'Post-peak clip duration in ms',
#  'merge_thresh_cc': 'Cross-correlogram merging threshold, set to 1 to disable',
#  'nRepeat_merge': 'Number of repeats for merge',
#  'merge_overlap_thresh': 'Knn-overlap merge threshold',
#  'chunk_mb': 'Chunk size in Mb for saving to binary format (default 500Mb)',
#  'n_jobs_bin': 'Number of jobs for saving to binary format (Default 1)'}

# %%
# parameter default values
ss.get_default_params('ironclust')
# Out:
# {'detect_sign': -1,
#  'adjacency_radius': 50,
#  'adjacency_radius_out': 100,
#  'detect_threshold': 3.5,
#  'prm_template_name': '',
#  'freq_min': 300,
#  'freq_max': 8000,
#  'merge_thresh': 0.985,
#  'pc_per_chan': 9,
#  'whiten': False,
#  'filter_type': 'bandpass',
#  'filter_detect_type': 'none',
#  'common_ref_type': 'trimmean',
#  'batch_sec_drift': 300,
#  'step_sec_drift': 20,
#  'knn': 30,
#  'n_jobs_bin': 1,
#  'chunk_mb': 500,
#  'min_count': 30,
#  'fGpu': True,
#  'fft_thresh': 8,
#  'fft_thresh_low': 0,
#  'nSites_whiten': 16,
#  'feature_type': 'gpca',
#  'delta_cut': 1,
#  'post_merge_mode': 1,
#  'sort_mode': 1,
#  'fParfor': False,
#  'filter': True,
#  'clip_pre': 0.25,
#  'clip_post': 0.75,
#  'merge_thresh_cc': 1,
#  'nRepeat_merge': 3,
#  'merge_overlap_thresh': 0.95}

# %%
# create our own paramter dict
params = {'detect_sign': -1,
 'adjacency_radius': 50,
 'adjacency_radius_out': 100,
 'detect_threshold': 3.5,
 'prm_template_name': '',
 'freq_min': 300,
 'freq_max': 8000,
 'merge_thresh': 0.7,
 'pc_per_chan': 9,
 'whiten': False,
 'filter_type': 'none',
 'filter_detect_type': 'none',
 'common_ref_type': 'trimmean',
 'batch_sec_drift': 300,
 'step_sec_drift': 20,
 'knn': 30,
 'n_jobs_bin': 32,
 'chunk_mb': 500,
 'min_count': 30,
 'fGpu': False,
 'fft_thresh': 8,
 'fft_thresh_low': 0,
 'nSites_whiten': 16,
 'feature_type': 'gpca',
 'delta_cut': 1,
 'post_merge_mode': 1,
 'sort_mode': 1,
 'fParfor': True,
 'filter': False,
 'clip_pre': 0.25,
 'clip_post': 0.75,
 'merge_thresh_cc': 1,
 'nRepeat_merge': 3,
 'merge_overlap_thresh': 0.95}

# %%
# run sorter
sorting_IC = ss.run_ironclust(recording_cache, 
                              output_folder=pjoin(pth, sess, 'processed/results_ic'), 
                              grouping_property='group', 
                              n_jobs=32, 
                              verbose=True,
                              **params)
print(f'Ironclust found {len(sorting_IC.get_unit_ids())} units')

# attempt to save sorting results in case of crash
sorting_IC.dump_to_dict()
sorting_IC.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_ic.pkl'))
# Out:
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/raw.mda (1/2), took 1.4s (345.9 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/raw.mda (1/2), took 1.4s (345.9 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 1.5s
#
# 	get_prinvec_: took 1.5s
#
# 	Detecting 1/2: 155138 spikes found (31414.3 spikes/s, 101.2 MB/s, took 4.9 s)
#
# 	Detecting 1/2: 155138 spikes found (31414.3 spikes/s, 101.2 MB/s, took 4.9 s)
#
# 	Detecting 2/2: 68841 spikes found (45055.9 spikes/s, 267.0 MB/s, took 1.5 s)
#
# 	Detecting 2/2: 68841 spikes found (45055.9 spikes/s, 267.0 MB/s, took 1.5 s)
#
# Detection took 6.9s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Detection took 6.9s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 0.1s.
#
# took 0.1s.
#
# Clustering
#
# Clustering
#
# Calculating drift similarity...Calculating drift similarity...
#
# 	took 0.4s
#
#
#
# 	took 0.4s
#
# sort_page_: calculating Rho...
#
# sort_page_: calculating Rho...
#
# Page 1/2 Page 1/2 .. took 2.0s
#
#  took 2.0s
#
# Page 2/2 Page 2/2 .. took 1.1s
#
#  took 1.1s
#
# calculating Rho took 3.0s
#
# calculating Rho took 3.0s
#
# sort_page_: calculating Delta...
#
# sort_page_: calculating Delta...
#
# Page 1/2 Page 1/2 .. took 5.1s
#
#  took 5.1s
#
# Page 2/2 Page 2/2 .. took 4.8s
#
#  took 4.8s
#
# calculating Delta took 9.9s
#
# calculating Delta took 9.9s
#
# sort_long_: took 12.9s (fGpu=0, fParfor=0)
#
# sort_long_: took 12.9s (fGpu=0, fParfor=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
# auto-merging...
#
#
#
# auto-merging...
#
# 	postCluster_...
#
# 	postCluster_...
#
# 	cell2map_: 	cell2map_: ...... nRepeat=4, took 0.0s
#
#  nRepeat=4, took 0.0s
#
# 	nRepeat:1, n0=0
#
# 	nRepeat:1, n0=0
#
# 	postCluster_: Pre-merged 100->8->8 clusters, took 0.1s
#
# 	postCluster_: Pre-merged 100->8->8 clusters, took 0.1s
#
# 	isolation_score_: took 0.2s
#
# 	isolation_score_: took 0.2s
#
# 	cell2map_: 	cell2map_: .... nRepeat=3, took 0.0s
#
#  nRepeat=3, took 0.0s
#
# 	knn_overlap_merge_: 8->2 units
#
# 	knn_overlap_merge_: 8->2 units
#
# Removed 0/223979 (0.0%) duplicate spikes, took 0.0s
#
# Removed 0/223979 (0.0%) duplicate spikes, took 0.0s
#
# 	Merging templates...
#
# 		Merging templates...
#
# 	..
#
#
#
# 	cell2map_: 	cell2map_: .. nRepeat=2, took 0.0s
#
#  nRepeat=2, took 0.0s
#
# 	Merged waveforms (2->2->1), took 1.0s
#
# 	Merged waveforms (2->2->1), took 1.0s
#
# Removed 0/79877 (0.0%) duplicate spikes, took 0.0s
#
# Removed 0/79877 (0.0%) duplicate spikes, took 0.0s
#
# 	auto-merging took 1.5s (fGpu=0, fParfor=0)
#
# 	auto-merging took 1.5s (fGpu=0, fParfor=0)
#
# 	isolation_score_: took 0.0s
#
# 	isolation_score_: took 0.0s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.0s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.0s
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
#
#
# ------------------------------
#
# ------------------------------
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Recording format
#
# Recording format
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/raw.mda
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                223979
#
#     #Spikes:                223979
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              1
#
#     #Clusters:              1
#
#     #Unique events:         79877
#
#     #Unique events:         79877
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   6.9s
#
#     Detect + feature (s):   6.9s
#
#     Cluster runtime (s):    13.4s
#
#     Cluster runtime (s):    13.4s
#
#     merge runtime (s):      1.5s
#
#     merge runtime (s):      1.5s
#
#     Total runtime (s):      21.8s
#
#     Total runtime (s):      21.8s
#
#     Runtime speed:          x346.7 realtime
#
#     Runtime speed:          x346.7 realtime
#
#     Processing speed:       10262.9 spikes/s
#
#     Processing speed:       10262.9 spikes/s
#
# memory usage (GiB):         0.206
#
# memory usage (GiB):         0.206
#
#     detect:                 0.190
#
#     detect:                 0.190
#
#     sort:                   0.198
#
#     sort:                   0.198
#
#     auto-merge:             0.206
#
#     auto-merge:             0.206
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/0/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#28.880#
#
# #SF-SORTER-RUNTIME#28.880#
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/raw.mda (1/2), took 1.4s (367.6 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/raw.mda (1/2), took 1.4s (367.6 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 2.0s
#
# 	get_prinvec_: took 2.0s
#
# 	Detecting 1/2: 772758 spikes found (133342.9 spikes/s, 86.3 MB/s, took 5.8 s)
#
# 	Detecting 1/2: 772758 spikes found (133342.9 spikes/s, 86.3 MB/s, took 5.8 s)
#
# 	Detecting 2/2: 635804 spikes found (168504.7 spikes/s, 108.1 MB/s, took 3.8 s)
#
# 	Detecting 2/2: 635804 spikes found (168504.7 spikes/s, 108.1 MB/s, took 3.8 s)
#
# Detection took 11.4s and used 0.186 GiB (fParfor=0, fGpu=0)
#
# Detection took 11.4s and used 0.186 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 1.0s.
#
# took 1.0s.
#
# Clustering
#
# Clustering
#
# Calculating drift similarity...Calculating drift similarity...
#
# 	took 0.3s
#
#
#
# 	took 0.3s
#
# sort_page_: calculating Rho...
#
# sort_page_: calculating Rho...
#
# Page 1/2 Page 1/2 .. took 30.7s
#
#  took 30.7s
#
# Page 2/2 Page 2/2 .. took 29.5s
#
#  took 29.5s
#
# calculating Rho took 60.2s
#
# calculating Rho took 60.2s
#
# sort_page_: calculating Delta...
#
# sort_page_: calculating Delta...
#
# Page 1/2 Page 1/2 .. took 240.0s
#
#  took 240.0s
#
# Page 2/2 Page 2/2 .. took 232.0s
#
#  took 232.0s
#
# calculating Delta took 472.0s
#
# calculating Delta took 472.0s
#
# sort_long_: took 532.2s (fGpu=0, fParfor=0)
#
# sort_long_: took 532.2s (fGpu=0, fParfor=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
# auto-merging...
#
#
#
# auto-merging...
#
# 	postCluster_...
#
# 	postCluster_...
#
# 	cell2map_: 	cell2map_: ........ nRepeat=5, took 0.1s
#
#  nRepeat=5, took 0.1s
#
# 	nRepeat:1, n0=0
#
# 	nRepeat:1, n0=0
#
# 	postCluster_: Pre-merged 458->91->85 clusters, took 0.7s
#
# 	postCluster_: Pre-merged 458->91->85 clusters, took 0.7s
#
# 	isolation_score_: took 1.1s
#
# 	isolation_score_: took 1.1s
#
# 	cell2map_: 	cell2map_: ...... nRepeat=4, took 0.0s
#
#  nRepeat=4, took 0.0s
#
# 	knn_overlap_merge_: 85->9 units
#
# 	knn_overlap_merge_: 85->9 units
#
# Removed 0/1408494 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/1408494 (0.0%) duplicate spikes, took 0.1s
#
# 	Merging templates...
#
# 		Merging templates...
#
# 	..
#
#
#
# 	cell2map_: 	cell2map_: .. nRepeat=2, took 0.0s
#
#  nRepeat=2, took 0.0s
#
# 	Merged waveforms (9->1->1), took 4.7s
#
# 	Merged waveforms (9->1->1), took 4.7s
#
# Removed 0/1408494 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/1408494 (0.0%) duplicate spikes, took 0.1s
#
# 	auto-merging took 7.5s (fGpu=0, fParfor=0)
#
# 	auto-merging took 7.5s (fGpu=0, fParfor=0)
#
# 	isolation_score_: took 0.6s
#
# 	isolation_score_: took 0.6s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: took 0.4s.
#
# took 0.4s.
#
#
#
#
#
# ------------------------------
#
# ------------------------------
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Recording format
#
# Recording format
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/raw.mda
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                1408562
#
#     #Spikes:                1408562
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              1
#
#     #Clusters:              1
#
#     #Unique events:         1408494
#
#     #Unique events:         1408494
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   11.4s
#
#     Detect + feature (s):   11.4s
#
#     Cluster runtime (s):    532.6s
#
#     Cluster runtime (s):    532.6s
#
#     merge runtime (s):      7.5s
#
#     merge runtime (s):      7.5s
#
#     Total runtime (s):      551.4s
#
#     Total runtime (s):      551.4s
#
#     Runtime speed:          x13.7 realtime
#
#     Runtime speed:          x13.7 realtime
#
#     Processing speed:       2554.3 spikes/s
#
#     Processing speed:       2554.3 spikes/s
#
# memory usage (GiB):         0.684
#
# memory usage (GiB):         0.684
#
#     detect:                 0.186
#
#     detect:                 0.186
#
#     sort:                   0.311
#
#     sort:                   0.311
#
#     auto-merge:             0.684
#
#     auto-merge:             0.684
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/1/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#564.792#
#
# #SF-SORTER-RUNTIME#564.792#
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/raw.mda (1/2), took 0.8s (596.0 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/raw.mda (1/2), took 0.8s (596.0 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 1.9s
#
# 	get_prinvec_: took 1.9s
#
# 	Detecting 1/2: 698182 spikes found (133462.7 spikes/s, 95.6 MB/s, took 5.2 s)
#
# 	Detecting 1/2: 698182 spikes found (133462.7 spikes/s, 95.6 MB/s, took 5.2 s)
#
# 	Detecting 2/2: 490880 spikes found (282452.6 spikes/s, 234.7 MB/s, took 1.7 s)
#
# 	Detecting 2/2: 490880 spikes found (282452.6 spikes/s, 234.7 MB/s, took 1.7 s)
#
# Detection took 7.3s and used 0.191 GiB (fParfor=0, fGpu=0)
#
# Detection took 7.3s and used 0.191 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 0.0s.
#
# took 0.0s.
#
# Clustering
#
# Clustering
#
# Calculating drift similarity...Calculating drift similarity...
#
# 	took 0.2s
#
#
#
# 	took 0.2s
#
# sort_page_: calculating Rho...
#
# sort_page_: calculating Rho...
#
# Page 1/2 Page 1/2 .. took 22.3s
#
#  took 22.3s
#
# Page 2/2 Page 2/2 .. took 21.4s
#
#  took 21.4s
#
# calculating Rho took 43.7s
#
# calculating Rho took 43.7s
#
# sort_page_: calculating Delta...
#
# sort_page_: calculating Delta...
#
# Page 1/2 Page 1/2 .. took 171.1s
#
#  took 171.1s
#
# Page 2/2 Page 2/2 .. took 165.0s
#
#  took 165.0s
#
# calculating Delta took 336.1s
#
# calculating Delta took 336.1s
#
# sort_long_: took 379.9s (fGpu=0, fParfor=0)
#
# sort_long_: took 379.9s (fGpu=0, fParfor=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
# auto-merging...
#
#
#
# auto-merging...
#
# 	postCluster_...
#
# 	postCluster_...
#
# 	cell2map_: 	cell2map_: ........ nRepeat=5, took 0.1s
#
#  nRepeat=5, took 0.1s
#
# 	nRepeat:1, n0=0
#
# 	nRepeat:1, n0=0
#
# 	postCluster_: Pre-merged 415->75->64 clusters, took 0.6s
#
# 	postCluster_: Pre-merged 415->75->64 clusters, took 0.6s
#
# 	isolation_score_: took 1.0s
#
# 	isolation_score_: took 1.0s
#
# 	cell2map_: 	cell2map_: ...... nRepeat=4, took 0.0s
#
#  nRepeat=4, took 0.0s
#
# 	knn_overlap_merge_: 64->8 units
#
# 	knn_overlap_merge_: 64->8 units
#
# Removed 0/1188975 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/1188975 (0.0%) duplicate spikes, took 0.1s
#
# 	Merging templates...
#
# 		Merging templates...
#
# 	..
#
#
#
# 	cell2map_: 	cell2map_: .. nRepeat=2, took 0.0s
#
#  nRepeat=2, took 0.0s
#
# 	Merged waveforms (8->2->1), took 4.0s
#
# 	Merged waveforms (8->2->1), took 4.0s
#
# Removed 0/1147492 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/1147492 (0.0%) duplicate spikes, took 0.1s
#
# 	auto-merging took 6.3s (fGpu=0, fParfor=0)
#
# 	auto-merging took 6.3s (fGpu=0, fParfor=0)
#
# 	isolation_score_: took 0.5s
#
# 	isolation_score_: took 0.5s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
#
#
# ------------------------------
#
# ------------------------------
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Recording format
#
# Recording format
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/raw.mda
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                1189062
#
#     #Spikes:                1189062
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              1
#
#     #Clusters:              1
#
#     #Unique events:         1147492
#
#     #Unique events:         1147492
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   7.3s
#
#     Detect + feature (s):   7.3s
#
#     Cluster runtime (s):    380.2s
#
#     Cluster runtime (s):    380.2s
#
#     merge runtime (s):      6.3s
#
#     merge runtime (s):      6.3s
#
#     Total runtime (s):      393.9s
#
#     Total runtime (s):      393.9s
#
#     Runtime speed:          x19.2 realtime
#
#     Runtime speed:          x19.2 realtime
#
#     Processing speed:       3019.0 spikes/s
#
#     Processing speed:       3019.0 spikes/s
#
# memory usage (GiB):         0.596
#
# memory usage (GiB):         0.596
#
#     detect:                 0.191
#
#     detect:                 0.191
#
#     sort:                   0.316
#
#     sort:                   0.316
#
#     auto-merge:             0.596
#
#     auto-merge:             0.596
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/2/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#399.245#
#
# #SF-SORTER-RUNTIME#399.245#
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/raw.mda (1/2), took 0.9s (535.8 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/raw.mda (1/2), took 0.9s (535.8 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 1.4s
#
# 	get_prinvec_: took 1.4s
#
# 	Detecting 1/2: 549629 spikes found (117032.4 spikes/s, 106.5 MB/s, took 4.7 s)
#
# 	Detecting 1/2: 549629 spikes found (117032.4 spikes/s, 106.5 MB/s, took 4.7 s)
#
# 	Detecting 2/2: 398338 spikes found (242524.8 spikes/s, 248.4 MB/s, took 1.6 s)
#
# 	Detecting 2/2: 398338 spikes found (242524.8 spikes/s, 248.4 MB/s, took 1.6 s)
#
# Detection took 6.6s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Detection took 6.6s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 0.0s.
#
# took 0.0s.
#
# Clustering
#
# Clustering
#
# Calculating drift similarity...Calculating drift similarity...
#
# 	took 0.2s
#
#
#
# 	took 0.2s
#
# sort_page_: calculating Rho...
#
# sort_page_: calculating Rho...
#
# Page 1/2 Page 1/2 .. took 14.5s
#
#  took 14.5s
#
# Page 2/2 Page 2/2 .. took 13.8s
#
#  took 13.8s
#
# calculating Rho took 28.4s
#
# calculating Rho took 28.4s
#
# sort_page_: calculating Delta...
#
# sort_page_: calculating Delta...
#
# Page 1/2 Page 1/2 .. took 106.5s
#
#  took 106.5s
#
# Page 2/2 Page 2/2 .. took 103.2s
#
#  took 103.2s
#
# calculating Delta took 209.7s
#
# calculating Delta took 209.7s
#
# sort_long_: took 238.0s (fGpu=0, fParfor=0)
#
# sort_long_: took 238.0s (fGpu=0, fParfor=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
# auto-merging...
#
#
#
# auto-merging...
#
# 	postCluster_...
#
# 	postCluster_...
#
# 	cell2map_: 	cell2map_: ........ nRepeat=5, took 0.1s
#
#  nRepeat=5, took 0.1s
#
# 	nRepeat:1, n0=0
#
# 	nRepeat:1, n0=0
#
# 	postCluster_: Pre-merged 402->38->33 clusters, took 0.5s
#
# 	postCluster_: Pre-merged 402->38->33 clusters, took 0.5s
#
# 	isolation_score_: took 0.6s
#
# 	isolation_score_: took 0.6s
#
# 	cell2map_: 	cell2map_: .... nRepeat=3, took 0.0s
#
#  nRepeat=3, took 0.0s
#
# 	knn_overlap_merge_: 33->6 units
#
# 	knn_overlap_merge_: 33->6 units
#
# Removed 0/947931 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/947931 (0.0%) duplicate spikes, took 0.1s
#
# 	Merging templates...
#
# 		Merging templates...
#
# 	..
#
#
#
# 	cell2map_: 	cell2map_: .. nRepeat=2, took 0.0s
#
#  nRepeat=2, took 0.0s
#
# 	Merged waveforms (6->1->1), took 3.2s
#
# 	Merged waveforms (6->1->1), took 3.2s
#
# Removed 0/947931 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/947931 (0.0%) duplicate spikes, took 0.1s
#
# 	auto-merging took 4.9s (fGpu=0, fParfor=0)
#
# 	auto-merging took 4.9s (fGpu=0, fParfor=0)
#
# 	isolation_score_: took 0.3s
#
# 	isolation_score_: took 0.3s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
#
#
# ------------------------------
#
# ------------------------------
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Recording format
#
# Recording format
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/raw.mda
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                947967
#
#     #Spikes:                947967
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              1
#
#     #Clusters:              1
#
#     #Unique events:         947931
#
#     #Unique events:         947931
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   6.6s
#
#     Detect + feature (s):   6.6s
#
#     Cluster runtime (s):    238.4s
#
#     Cluster runtime (s):    238.4s
#
#     merge runtime (s):      4.9s
#
#     merge runtime (s):      4.9s
#
#     Total runtime (s):      249.9s
#
#     Total runtime (s):      249.9s
#
#     Runtime speed:          x30.3 realtime
#
#     Runtime speed:          x30.3 realtime
#
#     Processing speed:       3793.1 spikes/s
#
#     Processing speed:       3793.1 spikes/s
#
# memory usage (GiB):         0.468
#
# memory usage (GiB):         0.468
#
#     detect:                 0.190
#
#     detect:                 0.190
#
#     sort:                   0.232
#
#     sort:                   0.232
#
#     auto-merge:             0.468
#
#     auto-merge:             0.468
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/3/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#255.083#
#
# #SF-SORTER-RUNTIME#255.083#
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/ironclust_dataset/raw.mda (1/2), took 1.0s (497.5 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/ironclust_dataset/raw.mda (1/2), took 1.0s (497.5 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 1.5s
#
# 	get_prinvec_: took 1.5s
#
# 	Detecting 1/2: 785667 spikes found (159218.4 spikes/s, 101.3 MB/s, took 4.9 s)
#
# 	Detecting 1/2: 785667 spikes found (159218.4 spikes/s, 101.3 MB/s, took 4.9 s)
#
# 	Detecting 2/2: 632820 spikes found (294808.9 spikes/s, 190.1 MB/s, took 2.1 s)
#
# 	Detecting 2/2: 632820 spikes found (294808.9 spikes/s, 190.1 MB/s, took 2.1 s)
#
# Detection took 7.4s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Detection took 7.4s and used 0.190 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/4/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 0.1s.
#
# took 0.1s.
#
# ...
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                1435221
#
#     #Spikes:                1435221
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              4
#
#     #Clusters:              4
#
#     #Unique events:         1424874
#
#     #Unique events:         1424874
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   7.1s
#
#     Detect + feature (s):   7.1s
#
#     Cluster runtime (s):    560.5s
#
#     Cluster runtime (s):    560.5s
#
#     merge runtime (s):      7.1s
#
#     merge runtime (s):      7.1s
#
#     Total runtime (s):      574.7s
#
#     Total runtime (s):      574.7s
#
#     Runtime speed:          x13.2 realtime
#
#     Runtime speed:          x13.2 realtime
#
#     Processing speed:       2497.4 spikes/s
#
#     Processing speed:       2497.4 spikes/s
#
# memory usage (GiB):         0.619
#
# memory usage (GiB):         0.619
#
#     detect:                 0.190
#
#     detect:                 0.190
#
#     sort:                   0.325
#
#     sort:                   0.325
#
#     auto-merge:             0.619
#
#     auto-merge:             0.619
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/94/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#580.581#
#
# #SF-SORTER-RUNTIME#580.581#
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Creating argfile.txt...
# Running ironclust in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/run_ironclust.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# ===================================================
#
# ===================================================
#
# IronClust Version: 2
#
# IronClust Version: 2
#
# ===================================================
#
# ===================================================
#
# Removed 0 lock(s).
#
# Removed 0 lock(s).
#
# Running irc2.m (5.9.8)
#
# Running irc2.m (5.9.8)
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
# Created /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/raw.mda (1/2), took 0.9s (540.2 MB/s, 500.0 MB)
#
# Read /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/raw.mda (1/2), took 0.9s (540.2 MB/s, 500.0 MB)
#
# 	get_prinvec_: took 1.1s
#
# 	get_prinvec_: took 1.1s
#
# 	Detecting 1/2: 583104 spikes found (149435.8 spikes/s, 128.1 MB/s, took 3.9 s)
#
# 	Detecting 1/2: 583104 spikes found (149435.8 spikes/s, 128.1 MB/s, took 3.9 s)
#
# 	Detecting 2/2: 457736 spikes found (254219.1 spikes/s, 226.6 MB/s, took 1.8 s)
#
# 	Detecting 2/2: 457736 spikes found (254219.1 spikes/s, 226.6 MB/s, took 1.8 s)
#
# Detection took 6.0s and used 0.191 GiB (fParfor=0, fGpu=0)
#
# Detection took 6.0s and used 0.191 GiB (fParfor=0, fGpu=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/detect_irc.mat: took 0.1s.
#
# took 0.1s.
#
# Clustering
#
# Clustering
#
# Calculating drift similarity...Calculating drift similarity...
#
# 	took 0.3s
#
#
#
# 	took 0.3s
#
# sort_page_: calculating Rho...
#
# sort_page_: calculating Rho...
#
# Page 1/2 Page 1/2 .. took 17.3s
#
#  took 17.3s
#
# Page 2/2 Page 2/2 .. took 16.6s
#
#  took 16.6s
#
# calculating Rho took 33.9s
#
# calculating Rho took 33.9s
#
# sort_page_: calculating Delta...
#
# sort_page_: calculating Delta...
#
# Page 1/2 Page 1/2 .. took 129.0s
#
#  took 129.0s
#
# Page 2/2 Page 2/2 .. took 131.9s
#
#  took 131.9s
#
# calculating Delta took 260.9s
#
# calculating Delta took 260.9s
#
# sort_long_: took 294.9s (fGpu=0, fParfor=0)
#
# sort_long_: took 294.9s (fGpu=0, fParfor=0)
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/sort_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
# auto-merging...
#
#
#
# auto-merging...
#
# 	postCluster_...
#
# 	postCluster_...
#
# 	cell2map_: 	cell2map_: ........ nRepeat=5, took 0.1s
#
#  nRepeat=5, took 0.1s
#
# 	nRepeat:1, n0=2
#
# 	nRepeat:1, n0=2
#
# 	nRepeat:2, n0=0
#
# 	nRepeat:2, n0=0
#
# 	postCluster_: Pre-merged 308->36->30 clusters, took 0.6s
#
# 	postCluster_: Pre-merged 308->36->30 clusters, took 0.6s
#
# 	isolation_score_: took 0.9s
#
# 	isolation_score_: took 0.9s
#
# 	cell2map_: 	cell2map_: .... nRepeat=3, took 0.0s
#
#  nRepeat=3, took 0.0s
#
# 	knn_overlap_merge_: 30->2 units
#
# 	knn_overlap_merge_: 30->2 units
#
# Removed 0/1040778 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/1040778 (0.0%) duplicate spikes, took 0.1s
#
# 	Merging templates...
#
# 		Merging templates...
#
# 	..
#
#
#
# 	cell2map_: 	cell2map_: .. nRepeat=2, took 0.0s
#
#  nRepeat=2, took 0.0s
#
# 	Merged waveforms (2->2->1), took 3.1s
#
# 	Merged waveforms (2->2->1), took 3.1s
#
# Removed 0/301668 (0.0%) duplicate spikes, took 0.1s
#
# Removed 0/301668 (0.0%) duplicate spikes, took 0.1s
#
# 	auto-merging took 5.5s (fGpu=0, fParfor=0)
#
# 	auto-merging took 5.5s (fGpu=0, fParfor=0)
#
# 	isolation_score_: took 0.2s
#
# 	isolation_score_: took 0.2s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/firings.mda, took 0.1s
#
# Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: Saving a struct to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/detect_82b3fb2a6c48f1136b07e311a706ba6b/sort_b5e8be3adbd834d6471ca94e5d41d629/auto_af9034f7d40c9a876a52e92c62c20730/auto_irc.mat: took 0.0s.
#
# took 0.0s.
#
#
#
#
#
# ------------------------------
#
# ------------------------------
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
# Summary of /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Recording format
#
# Recording format
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/raw.mda
#
#     Recording file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/raw.mda
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/geom.csv
#
#     Probe file:             /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/ironclust_dataset/geom.csv
#
#     Recording Duration:     7566.4s
#
#     Recording Duration:     7566.4s
#
#     Data Type:              single
#
#     Data Type:              single
#
#     #Channels in file:      1
#
#     #Channels in file:      1
#
#     #Sites:                 1
#
#     #Sites:                 1
#
#     #Shanks:                1
#
#     #Shanks:                1
#
# Pre-processing
#
# Pre-processing
#
#     Filter type:            none
#
#     Filter type:            none
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Filter range (Hz):      [NaN, NaN]
#
#     Matched Filter:         0
#
#     Matched Filter:         0
#
#     Common ref:             trimmean
#
#     Common ref:             trimmean
#
#     Whiten:                 0
#
#     Whiten:                 0
#
#     FFT threshold:          8
#
#     FFT threshold:          8
#
#     blank threshold:        0
#
#     blank threshold:        0
#
# Events
#
# Events
#
#     #Spikes:                1040840
#
#     #Spikes:                1040840
#
#     Feature extracted:      gpca
#
#     Feature extracted:      gpca
#
#     #Sites/event:           1
#
#     #Sites/event:           1
#
#     maxDist_site_um:        50
#
#     maxDist_site_um:        50
#
#     maxDist_site_spk_um:    100
#
#     maxDist_site_spk_um:    100
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     spkLim_ms:              [-0.250, 0.750]
#
#     #PC/chan:               9
#
#     #PC/chan:               9
#
# Cluster
#
# Cluster
#
#     #Clusters:              1
#
#     #Clusters:              1
#
#     #Unique events:         301668
#
#     #Unique events:         301668
#
#     min. spk/clu:           30
#
#     min. spk/clu:           30
#
#     Cluster method:         drift-knn
#
#     Cluster method:         drift-knn
#
#     knn:                    30
#
#     knn:                    30
#
#     step_sec_drift:         20.0s
#
#     step_sec_drift:         20.0s
#
#     batch_sec_drift:        300.0s
#
#     batch_sec_drift:        300.0s
#
# Auto-merge
#
# Auto-merge
#
#     merge_overlap_thresh:   0.950
#
#     merge_overlap_thresh:   0.950
#
#     delta_cut:              1.000
#
#     delta_cut:              1.000
#
#     merge_thresh_cc:        1.000
#
#     merge_thresh_cc:        1.000
#
#     maxWavCor:              0.700
#
#     maxWavCor:              0.700
#
# Runtime (s)
#
# Runtime (s)
#
#     Detect + feature (s):   6.0s
#
#     Detect + feature (s):   6.0s
#
#     Cluster runtime (s):    295.3s
#
#     Cluster runtime (s):    295.3s
#
#     merge runtime (s):      5.5s
#
#     merge runtime (s):      5.5s
#
#     Total runtime (s):      306.8s
#
#     Total runtime (s):      306.8s
#
#     Runtime speed:          x24.7 realtime
#
#     Runtime speed:          x24.7 realtime
#
#     Processing speed:       3392.4 spikes/s
#
#     Processing speed:       3392.4 spikes/s
#
# memory usage (GiB):         0.507
#
# memory usage (GiB):         0.507
#
#     detect:                 0.191
#
#     detect:                 0.191
#
#     sort:                   0.259
#
#     sort:                   0.259
#
#     auto-merge:             0.507
#
#     auto-merge:             0.507
#
# Execution
#
# Execution
#
#     irc2 version:           5.9.8
#
#     irc2 version:           5.9.8
#
#     fGpu (GPU use):         0
#
#     fGpu (GPU use):         0
#
#     fParfor (parfor use):   0
#
#     fParfor (parfor use):   0
#
#     fLargeRecording:        1
#
#     fLargeRecording:        1
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
#     Parameter file:         /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/raw_geom.prm
#
# ------------------------------
#
# ------------------------------
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/firings.mda
#
# Clustering result wrote to /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_ic/95/tmp/firings.mda
#
# #SF-SORTER-RUNTIME#312.102#
#
# #SF-SORTER-RUNTIME#312.102#
# ironclust run time 24658.62s
# Ironclust found 243 units

# %% [markdown]
# ##### To Reload Ironclust sort from pkl (uncomment and run next cell)

# %%
sorting_IC = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/sorting_ic.pkl'))

# %% [markdown]
# ## Waveclus

# %%
# waveclus takes a long time. see parameters
ss.get_params_description('waveclus')
# Out:
# {'detect_threshold': 'Threshold for spike detection',
#  'detect_sign': 'Use -1 (negative), 1 (positive), or 0 (both) depending on the sign of the spikes in the recording',
#  'feature_type': 'wav (for wavelets) or pca, type of feature extraction applied to the spikes',
#  'scales': 'Levels of the wavelet decomposition used as features',
#  'min_clus': 'Minimum increase of cluster sizes used by the peak selection on the temperature map',
#  'maxtemp': 'Maximum temperature calculated by the SPC method',
#  'template_sdnum': 'Maximum distance (in total variance of the cluster) from the mean waveform to force a spike into a cluster',
#  'enable_detect_filter': 'Enable or disable filter on detection',
#  'enable_sort_filter': 'Enable or disable filter on sorting',
#  'detect_filter_fmin': 'High-pass filter cutoff frequency for detection',
#  'detect_filter_fmax': 'Low-pass filter cutoff frequency for detection',
#  'detect_filter_order': 'Order of the detection filter',
#  'sort_filter_fmin': 'High-pass filter cutoff frequency for sorting',
#  'sort_filter_fmax': 'Low-pass filter cutoff frequency for sorting',
#  'sort_filter_order': 'Order of the sorting filter',
#  'mintemp': 'Minimum temperature calculated by the SPC algorithm',
#  'w_pre': 'Number of samples from the beginning of the spike waveform up to (including) the peak',
#  'w_post': 'Number of samples from the peak (excluding it) to the end of the waveform',
#  'alignment_window': 'Number of samples between peaks of different channels',
#  'stdmax': 'The events with a value over this number of noise standard deviations will be discarded',
#  'max_spk': 'Maximum number of spikes used by the SPC algorithm',
#  'ref_ms': 'Refractory time in milliseconds, all the threshold crossing inside this period are detected as the same spike',
#  'interpolation': 'Enable or disable interpolation to improve the alignments of the spikes'}

# %%
# default values
ss.get_default_params('waveclus')
# Out:
# {'detect_threshold': 5,
#  'detect_sign': -1,
#  'feature_type': 'wav',
#  'scales': 4,
#  'min_clus': 20,
#  'maxtemp': 0.251,
#  'template_sdnum': 3,
#  'enable_detect_filter': True,
#  'enable_sort_filter': True,
#  'detect_filter_fmin': 300,
#  'detect_filter_fmax': 3000,
#  'detect_filter_order': 4,
#  'sort_filter_fmin': 300,
#  'sort_filter_fmax': 3000,
#  'sort_filter_order': 2,
#  'mintemp': 0,
#  'w_pre': 20,
#  'w_post': 44,
#  'alignment_window': 10,
#  'stdmax': 50,
#  'max_spk': 40000,
#  'ref_ms': 1.5,
#  'interpolation': True}

# %%
# modify parameters
params = {'detect_threshold': 4,
 'detect_sign': -1,
 'feature_type': 'wav',
 'scales': 4,
 'min_clus': 40,
 'maxtemp': 0.251,
 'template_sdnum': 3,
 'enable_detect_filter': False,
 'enable_sort_filter': False,
 'detect_filter_fmin': 300,
 'detect_filter_fmax': 3000,
 'detect_filter_order': 4,
 'sort_filter_fmin': 300,
 'sort_filter_fmax': 3000,
 'sort_filter_order': 2,
 'mintemp': 0,
 'w_pre': 20,
 'w_post': 44,
 'alignment_window': 10,
 'stdmax': 50,
 'max_spk': 40000,
 'ref_ms': 1.5,
 'interpolation': True}

# %%
# run sorter
sorting_WC = ss.run_waveclus(recording_cache, 
                             output_folder=pjoin(pth, sess, 'processed/results_wc'), 
                             grouping_property='group', 
                             n_jobs=32, 
                             verbose=True,
                             **params)
print(f'Waveclus found {len(sorting_WC.get_unit_ids())} units')

# attempt to save sorting results in case of crash
sorting_WC.dump_to_dict()
sorting_WC.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_wc.pkl'))
# Out:
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/0...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/0/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (440.09s).
#
# Computations Done (440.09s).
#
# Elapsed time is 440.094774 seconds.
#
# Elapsed time is 440.094774 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/1...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/1/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (444.09s).
#
# Computations Done (444.09s).
#
# Elapsed time is 444.092285 seconds.
#
# Elapsed time is 444.092285 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/2...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/2/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (447.61s).
#
# Computations Done (447.61s).
#
# Elapsed time is 447.618702 seconds.
#
# Elapsed time is 447.618702 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/3...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/3/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (446.10s).
#
# Computations Done (446.10s).
#
# Elapsed time is 446.102760 seconds.
#
# Elapsed time is 446.102760 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/4...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/4/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (452.12s).
#
# Computations Done (452.12s).
#
# Elapsed time is 452.124913 seconds.
#
# Elapsed time is 452.124913 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/5...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/5/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (454.59s).
#
# Computations Done (454.59s).
#
# Elapsed time is 454.597807 seconds.
#
# Elapsed time is 454.597807 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/6...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/6/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (457.22s).
#
# Computations Done (457.22s).
#
# Elapsed time is 457.227632 seconds.
#
# Elapsed time is 457.227632 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/7...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/7/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (456.10s).
#
# Computations Done (456.10s).
#
# Elapsed time is 456.106886 seconds.
#
# Elapsed time is 456.106886 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/8...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/8/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (444.48s).
#
# Computations Done (444.48s).
#
# Elapsed time is 444.482974 seconds.
#
# Elapsed time is 444.482974 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/9...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/9/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (449.09s).
#
# Computations Done (449.09s).
#
# Elapsed time is 449.094915 seconds.
#
# Elapsed time is 449.094915 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/10...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/10/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (425.49s).
#
# Computations Done (425.49s).
#
# Elapsed time is 425.501302 seconds.
#
# Elapsed time is 425.501302 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/11...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/11/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (443.67s).
#
# Computations Done (443.67s).
#
# Elapsed time is 443.670662 seconds.
#
# Elapsed time is 443.670662 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/12...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/12/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (279.35s).
#
# Computations Done (279.35s).
#
# Elapsed time is 279.353222 seconds.
#
# Elapsed time is 279.353222 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/13...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/13/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (420.38s).
#
# Computations Done (420.38s).
#
# Elapsed time is 420.395492 seconds.
#
# Elapsed time is 420.395492 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/14...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/14/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (101.82s).
#
# Computations Done (101.82s).
#
# Elapsed time is 101.827391 seconds.
#
# Elapsed time is 101.827391 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/15...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/15/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (423.07s).
#
# Computations Done (423.07s).
#
# Elapsed time is 423.074344 seconds.
#
# Elapsed time is 423.074344 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/16...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/16/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (420.08s).
#
# Computations Done (420.08s).
#
# Elapsed time is 420.089288 seconds.
#
# Elapsed time is 420.089288 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/17...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/17/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (100.16s).
#
# Computations Done (100.16s).
#
# Elapsed time is 100.164300 seconds.
#
# Elapsed time is 100.164300 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/18...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/18/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (100.65s).
#
# Computations Done (100.65s).
#
# Elapsed time is 100.658051 seconds.
#
# Elapsed time is 100.658051 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/19...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/19/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (415.82s).
#
# Computations Done (415.82s).
#
# Elapsed time is 415.827228 seconds.
#
# Elapsed time is 415.827228 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/20...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/20/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (429.69s).
#
# Computations Done (429.69s).
#
# Elapsed time is 429.699091 seconds.
#
# Elapsed time is 429.699091 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/21...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/21/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (79.11s).
#
# Computations Done (79.11s).
#
# Elapsed time is 79.112417 seconds.
#
# Elapsed time is 79.112417 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/22...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/22/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (413.27s).
#
# Computations Done (413.27s).
#
# Elapsed time is 413.284709 seconds.
#
# Elapsed time is 413.284709 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/23...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/23/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (443.90s).
#
# Computations Done (443.90s).
#
# Elapsed time is 443.905942 seconds.
#
# Elapsed time is 443.905942 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/24...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/24/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (99.03s).
#
# Computations Done (99.03s).
#
# Elapsed time is 99.033329 seconds.
#
# Elapsed time is 99.033329 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/25...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/25/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (75.06s).
#
# Computations Done (75.06s).
#
# Elapsed time is 75.067699 seconds.
#
# Elapsed time is 75.067699 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/26...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/26/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (414.88s).
#
# Computations Done (414.88s).
#
# Elapsed time is 414.884534 seconds.
#
# Elapsed time is 414.884534 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/27...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/27/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (414.20s).
#
# Computations Done (414.20s).
#
# Elapsed time is 414.210306 seconds.
#
# Elapsed time is 414.210306 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/28...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/28/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (121.68s).
#
# Computations Done (121.68s).
#
# Elapsed time is 121.685725 seconds.
#
# Elapsed time is 121.685725 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/29...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/29/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (63.77s).
#
# Computations Done (63.77s).
#
# Elapsed time is 63.776239 seconds.
#
# Elapsed time is 63.776239 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/30...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/30/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (420.65s).
#
# Computations Done (420.65s).
#
# Elapsed time is 420.651271 seconds.
#
# Elapsed time is 420.651271 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/31...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/31/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (424.81s).
#
# Computations Done (424.81s).
#
# Elapsed time is 424.816424 seconds.
#
# Elapsed time is 424.816424 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/32...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/32/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (414.92s).
#
# Computations Done (414.92s).
#
# Elapsed time is 414.931721 seconds.
#
# Elapsed time is 414.931721 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/33...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/33/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
# ...
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (430.85s).
#
# Computations Done (430.85s).
#
# Elapsed time is 430.852563 seconds.
#
# Elapsed time is 430.852563 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/85...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/85/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (426.69s).
#
# Computations Done (426.69s).
#
# Elapsed time is 426.702792 seconds.
#
# Elapsed time is 426.702792 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/86...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/86/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (428.49s).
#
# Computations Done (428.49s).
#
# Elapsed time is 428.493905 seconds.
#
# Elapsed time is 428.493905 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/87...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/87/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (430.18s).
#
# Computations Done (430.18s).
#
# Elapsed time is 430.181975 seconds.
#
# Elapsed time is 430.181975 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/88...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/88/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (422.36s).
#
# Computations Done (422.36s).
#
# Elapsed time is 422.361995 seconds.
#
# Elapsed time is 422.361995 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/89...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/89/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (431.02s).
#
# Computations Done (431.02s).
#
# Elapsed time is 431.023660 seconds.
#
# Elapsed time is 431.023660 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/90...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/90/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (426.00s).
#
# Computations Done (426.00s).
#
# Elapsed time is 426.006066 seconds.
#
# Elapsed time is 426.006066 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/91...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/91/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (418.63s).
#
# Computations Done (418.63s).
#
# Elapsed time is 418.646276 seconds.
#
# Elapsed time is 418.646276 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/92...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/92/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (419.16s).
#
# Computations Done (419.16s).
#
# Elapsed time is 419.166537 seconds.
#
# Elapsed time is 419.166537 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/93...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/93/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (419.43s).
#
# Computations Done (419.43s).
#
# Elapsed time is 419.445151 seconds.
#
# Elapsed time is 419.445151 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/94...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/94/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (422.63s).
#
# Computations Done (422.63s).
#
# Elapsed time is 422.634914 seconds.
#
# Elapsed time is 422.634914 seconds.
#
# Warning! The recording is already filtered, but Wave-Clus filters are enabled. You can disable filters by setting 'enable_detect_filter' and 'enable_sort_filter' parameters to False
# Num. channels = 1, Num. timepoints = 226990993, duration = 126.10610722222222 minutes
# Running waveclus in /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/95...
# RUNNING SHELL SCRIPT: /project/nicho/data/marmosets/electrophys_data_for_processing/MG20230416_1505_mothsAndFree/processed/results_wc/95/run_waveclus.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2022 The MathWorks, Inc.
#
#                   R2022b (9.13.0.2049777) 64-bit (glnxa64)
#
#                               August 24, 2022
#
#
#
#
# To get started, type doc.
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
# For product information, visit www.mathworks.com.
#
#
#
#
#
# 1 of 1 'spikes' files done.
#
# 1 of 1 'spikes' files done.
#
# 0 of 1 'times' files finished.
#
# 0 of 1 'times' files finished.
#
# Computations Done (408.92s).
#
# Computations Done (408.92s).
#
# Elapsed time is 408.930320 seconds.
#
# Elapsed time is 408.930320 seconds.
#
# waveclus run time 39433.56s
# Waveclus found 299 units

# %% [markdown]
# ##### To Reload waveclus sort from pkl (uncomment and run next cell)

# %%
sorting_WC = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/sorting_wc.pkl'))

# %% [markdown]
# ## Klusta Kwik
# Only use if Tridesclous or kilosort doesn't work

# %%
# get the parameters
ss.get_params_description('klusta')

# %%
# default values
ss.get_default_params('klusta')

# %%
# modify parameters
params = {'adjacency_radius': None,
 'threshold_strong_std_factor': 5,
 'threshold_weak_std_factor': 2,
 'detect_sign': -1,
 'extract_s_before': 16,
 'extract_s_after': 32,
 'n_features_per_channel': 3,
 'pca_n_waveforms_max': 10000,
 'num_starting_clusters': 50,
 'chunk_mb': 500,
 'n_jobs_bin': 1}

# %%
# run sorter
sorting_KL = ss.run_klusta(recording_cache, 
                           output_folder=pjoin(pth, sess, 'processed/results_kl'),
                           grouping_property='group',
                           n_jobs=5, 
                           verbose=True, 
                           **params)
print(f'klusta found {len(sorting_KL.get_unit_ids())} units')

# %%
# attempt to save sorting results in case of crash
sorting_KL.dump_to_dict()
sorting_KL.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_kl.pkl'))

# %% [markdown]
# ## Try Kilosort
# You need a GPU to run kilosort. Additionally you need to compile the cuda mex files. See installation instructions for kilosort. Use ver 2.5 or 2.0. Version 3 has issues.

# %%
# try kilosort. it usually doesn't work with the marmoset data, but sometimes it does. Only use v2.5 or v2.0. 
# see params
ss.get_params_description('kilosort2_5')

# %%
# see default vales
ss.get_default_params('kilosort2_5')

# %%
# set desired parameter values
params = {'detect_threshold': 6,
 'projection_threshold': [5, 2],
 'preclust_threshold': 5,
 'car': True,
 'minFR': 0.1,
 'minfr_goodchannels': 0.1,
 'nblocks': 5,
 'sig': 20,
 'freq_min': 150,
 'sigmaMask': 60,
 'nPCs': 3,
 'ntbuff': 64,
 'nfilt_factor': 4,
 'NT': None,
 'keep_good_only': False,
 'chunk_mb': 500,
 'n_jobs_bin': 1}

# %%
# run sorter (dont worry if it crashes. Just go to the next cell). note that this sorter does not use the group
# parameter. Kilosort assumes electrode conatacts are <20um, so that a spatial signal is aquired. So it wont work
# with one channel. Might be able to finagle something with 3 channels, but needs development. 
sorting_KS = ss.run_kilosort2_5(recording_cache, 
                                output_folder=pjoin(pth, sess, 'processed/results_ks'), 
                                #grouping_property='group', 
                                n_jobs=5, 
                                verbose=True,
                                **params)
print(f'Kilosort2.5 found {len(sorting_KS.get_unit_ids())} units')

# %%
# attempt to save sorting results in case of crash
sorting_KS.dump_to_dict()
sorting_KS.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_ks.pkl'))

# %% [markdown]
# ## Try Tridesclous

# %%
# list the properties of sorter
ss.get_params_description('tridesclous')

# %%
# see what the default parameters are. These are the only parameters spikeinterface will let you modify.
ss.get_default_params('tridesclous')

# %%
# the paramters are dict. Make a new dict with the parameters you want. One thing you generally need to change is
# to remove the options for filtering, as the data is already preprocessed. Though sometimes this isn't an option 
# (well at least that I have figured out how to change)
params = {
    'freq_min': 400.0,
    'freq_max': 5000.0,
    'detect_sign': -1,
    'detect_threshold': 4,
    'peak_span_ms': 0.7,
    'wf_left_ms': -2.0,
    'wf_right_ms': 3.0,
    'feature_method': 'auto',
    'cluster_method': 'auto',
    'clean_catalogue_gui': False,
    'chunk_mb': 500,
    'n_jobs_bin': 1}

# %%
# run the sorter. Always try and run with the group option (this sorts each probe individually, which is what we
# want for blackrock arrays since each probe is ~400um away)
sorting_TDC = ss.run_tridesclous(recording_cache, 
                                 output_folder=pjoin(pth, sess, 'processed/results_tdc'), 
                                 grouping_property='group', 
                                 n_jobs=48, 
                                 verbose=True,
                                 **params)
print(f'Tridesclous found {len(sorting_TDC.get_unit_ids())} units')

# attempt to save sorting results in case of crash
sorting_TDC.dump_to_dict()
sorting_TDC.dump_to_pickle(pjoin(pth, sess, 'processed/sorting_tdc.pkl'))

# %% [markdown]
# ## Curating the spike sorting
# Curation means to check the output of the spike sorter and decide if it was accurate. This can genrally be done in three ways. Criteria: set thresholds for metrics and reject clusters that don't meet the threshold. For example: ISI violations, SNR, Distance from noise clusters, etc. Comparitive: This tries to find the same unit bewteen each sorter in a pairwise fashion. it then identifies units that are common to all of the sorters. According to the paper (see ref at top), four sorters provided the optimal information and performed well with little manual intervention. Manual: Examining each cluster to decide if it's a single unit or not.
#
# Here we take a combined approach of comapritive and criteria curation combined with manual validation. This allows the user to have the ultimate say and provides the oppurtunity to save multiunit clusters. There is no guarentee that clusters identified by all of the sorters is a single unit. There could be errors (the cluster is really garbage), splits (two of the clusters actually belong in the same cluster, or one cluster is aactually two cells), or some combintation (an identifed cluster is actually a seperable noise and unit cluster).

# %%
# compare sorter outputs. Its important here to have your primary sorter as the first sorter. The primary sorter 
# is the sort that you will actually process and use. I currently recommend using Ironclust with the default
# parameters as your primary sorters. The following code reflects this decision. If you want to use a different
# sorter as primary, you need to adjust the code below

mcmp = sc.compare_multiple_sorters([sorting_IC, sorting_WC, sorting_SC], ['IC', 'WC', 'SC'], 
                                   spiketrain_mode='union', n_jobs=1, 
                                   verbose=True)

# %%
# visualize comaprisons
w = sw.plot_multicomp_agreement(mcmp)
w = sw.plot_multicomp_agreement_by_sorter(mcmp)

# %%
# set agreement sorter. min agreement count is the number of sorters that had to agree to count the unit. Default
# is to use 4 (as per the paper)
agreement_sorting = mcmp.get_agreement_sorting(minimum_agreement_count=3)

# %%
# get the ids of the common units
ids = agreement_sorting.get_unit_ids()
# show user common unit ids from the primary sorter
print('Common Unit IDs: ', ids)

# %%
# crucial: cache main sorter and specify location of tmp directory. The tmp directory needs to exist in your system.
# This will eat a lot of space while its processing. I would recomment that you have 2TB+ free in the tmp directory
sorting_IC_cache = se.CacheSortingExtractor(sorting_IC, pjoin(pth, sess, 'processed/ic_sort_results_cache.dat'))
sorting_IC_cache.dump_to_pickle(pjoin(pth, sess, 'processed/ic_sorting_cache.pkl'))
os.makedirs(pjoin(pth, sess, 'processed/tmp/'), exist_ok=True)
sorting_IC_cache.set_tmp_folder(pjoin(pth, sess, 'processed/tmp/'))

# %%
sorting_IC_cache = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/ic_sorting_cache.pkl'))
sorting_IC_cache.set_tmp_folder(pjoin(pth, sess, 'processed/tmp/'))

# %%
# Export the data to phy for manual curation. This should work, but if it crashes, you will need to do the 
# processing separately. Use the code cells at the end of this docuiment to do that, than rerun this cell.
st.postprocessing.export_to_phy(recording_cache, sorting_IC_cache, 
                                output_folder=pjoin(pth, sess, 'processed/phy_IC'), 
                                ms_before=0.5, 
                                ms_after=1, 
                                compute_pc_features=True, 
                                compute_amplitudes=True, 
                                max_spikes_per_unit=None, 
                                compute_property_from_recording=False, 
                                n_jobs=48, 
                                recompute_info=False, 
                                save_property_or_features=False, 
                                verbose=True)

# %%
if 'sorting_IC' not in locals():
    sorting_IC = se.load_extractor_from_pickle(pjoin(pth, sess, 'processed/sorting_ic.pkl'))

# quality metrics
import seaborn as sns
# get quality metrics
quality_metrics = st.validation.compute_quality_metrics(sorting_IC, recording_cache, 
                                                        metric_names=['firing_rate', 'isi_violation', 'snr'], 
                                                        as_dataframe=True)
# plot the data
plt.figure()
# you can change these however you want to see the values
sns.scatterplot(data=quality_metrics, x="snr", y='isi_violation')

# %%
# Decide thresholds for quality metrics and ID sites that pass criteria
snr_thresh = 5
isi_viol_thresh = 0.5
duration = recording_cache.get_num_frames()
# first get ISI violations and see ids that pass
sorting_auto = st.curation.threshold_isi_violations(sorting_IC, isi_viol_thresh, 'greater', duration)
print('#: ', len(sorting_auto.get_unit_ids()))
print('IDs: ', sorting_auto.get_unit_ids())

# %%
# now threshold on snr, and additionally remove clusters that do not pass
sorting_auto = st.curation.threshold_snrs(sorting_auto, recording_cache, snr_thresh, 'less')
print('#: ', len(sorting_auto.get_unit_ids()))
print('IDs: ', sorting_auto.get_unit_ids())
ids = sorting_auto.get_unit_ids()

# %%
ids = sorting_auto.get_unit_ids()

# %%
# Auto label based on criteria and comparision analysis. We do that by labelling all clusters that passed our
# criteria as MUA. Then we go back and label all clusters that were found in all sorters as 'Good'(SU).
cfile = pjoin(pth, sess, 'processed/phy_IC/cluster_group.tsv')
cg = pd.read_csv(cfile, delimiter='\t')
cg.iloc[sorting_auto.get_unit_ids(), 1] = 'mua'
cg.iloc[ids, 1] = 'good'
cg.to_csv(cfile, index=False, sep='\t') # check to see if the correct units were marked

# %% [markdown]
# ### Done!
# You should now use Phy to manually curate the results. I recommend having Phy installed in a seprate environment. When you open Phy, all of the clusters should be labeled "mua" (gray), "good" (green), or unlabeled (white). They can also be labeled "noise" (dark gray). You can now go through and adjust the automated curation. You want to check that good units are indeed single units to you, and that none of the mua are actually single units. You also want to check for errors (which should be rare) like: A cluster needs to be split into two. Two clusters need to be mereged. The cluster is really some weird noise. A cluster acually has labeled the same events as another cluster. Remeber to save your work in phy through the menu often.

# %% [markdown]
# ### Saving the output/working with the data
#
# After completing the manual curation we can access the spike info directly from phy using python (phy output is in .npy) or matlab (using the numpy toolbox). Or you can reimport the data form phy and save as nwb or access directy (the spikeinterface format is really neo under the hood). The NWB part is still a work in progress and may be problematic. The method attempted here is to save the processed data. then append the sorted data to the NWB file created for the processed data.

# %%
import matplotlib.pyplot as plt
import spikeinterface
import spikeinterface.extractors as se 
import spikeinterface.toolkit as st
import spikeinterface.sorters as ss
import spikeinterface.comparison as sc
import spikeinterface.widgets as sw
import numpy as np
import pandas as pd
from os.path import join as pjoin
import os
import glob
import pynwb
sorting_IC_phy._properties
#(unit_ids=unitIDs, property_name='group')
# Out:
# {0: {'chan_group': '0', 'quality': 'noise'},
#  1: {'chan_group': '0', 'quality': 'good'},
#  3: {'chan_group': '0', 'quality': 'mua'},
#  4: {'chan_group': '0', 'quality': 'mua'},
#  7: {'chan_group': '0', 'quality': 'mua'},
#  9: {'chan_group': '0', 'quality': 'mua'},
#  12: {'chan_group': '0', 'quality': 'mua'},
#  13: {'chan_group': '0', 'quality': 'mua'},
#  16: {'chan_group': '0', 'quality': 'good'},
#  17: {'chan_group': '0', 'quality': 'mua'},
#  20: {'chan_group': '0', 'quality': 'mua'},
#  21: {'chan_group': '0', 'quality': 'mua'},
#  23: {'chan_group': '0', 'quality': 'mua'},
#  25: {'chan_group': '0', 'quality': 'mua'},
#  26: {'chan_group': '0', 'quality': 'mua'},
#  27: {'chan_group': '0', 'quality': 'mua'},
#  34: {'chan_group': '0', 'quality': 'good'},
#  35: {'chan_group': '0', 'quality': 'mua'},
#  36: {'chan_group': '0', 'quality': 'mua'},
#  39: {'chan_group': '0', 'quality': 'mua'},
#  41: {'chan_group': '0', 'quality': 'mua'},
#  43: {'chan_group': '0', 'quality': 'noise'},
#  47: {'chan_group': '0', 'quality': 'mua'},
#  48: {'chan_group': '0', 'quality': 'good'},
#  49: {'chan_group': '0', 'quality': 'mua'},
#  51: {'chan_group': '0', 'quality': 'mua'},
#  54: {'chan_group': '0', 'quality': 'mua'},
#  56: {'chan_group': '0', 'quality': 'noise'},
#  58: {'chan_group': '0', 'quality': 'good'},
#  59: {'chan_group': '0', 'quality': 'mua'},
#  61: {'chan_group': '0', 'quality': 'mua'},
#  64: {'chan_group': '0', 'quality': 'mua'},
#  69: {'chan_group': '0', 'quality': 'mua'},
#  70: {'chan_group': '0', 'quality': 'mua'},
#  71: {'chan_group': '0', 'quality': 'noise'},
#  72: {'chan_group': '0', 'quality': 'noise'},
#  73: {'chan_group': '0', 'quality': 'noise'},
#  74: {'chan_group': '0', 'quality': 'noise'},
#  75: {'chan_group': '0', 'quality': 'mua'},
#  79: {'chan_group': '0', 'quality': 'mua'},
#  80: {'chan_group': '0', 'quality': 'mua'},
#  81: {'chan_group': '0', 'quality': 'mua'},
#  83: {'chan_group': '0', 'quality': 'mua'},
#  84: {'chan_group': '0', 'quality': 'mua'},
#  89: {'chan_group': '0', 'quality': 'mua'},
#  90: {'chan_group': '0', 'quality': 'mua'},
#  92: {'chan_group': '0', 'quality': 'mua'},
#  99: {'chan_group': '0', 'quality': 'mua'},
#  100: {'chan_group': '0', 'quality': 'mua'},
#  107: {'chan_group': '0', 'quality': 'mua'},
#  113: {'chan_group': '0', 'quality': 'mua'},
#  114: {'chan_group': '0', 'quality': 'mua'},
#  116: {'chan_group': '0', 'quality': 'mua'},
#  117: {'chan_group': '0', 'quality': 'mua'},
#  125: {'chan_group': '0', 'quality': 'mua'},
#  132: {'chan_group': '0', 'quality': 'mua'},
#  137: {'chan_group': '0', 'quality': 'mua'},
#  138: {'chan_group': '0', 'quality': 'mua'},
#  139: {'chan_group': '0', 'quality': 'noise'},
#  142: {'chan_group': '0', 'quality': 'mua'},
#  146: {'chan_group': '0', 'quality': 'mua'},
#  147: {'chan_group': '0', 'quality': 'noise'},
#  149: {'chan_group': '0', 'quality': 'mua'},
#  153: {'chan_group': '0', 'quality': 'mua'},
#  170: {'chan_group': '0', 'quality': 'mua'},
#  177: {'quality': 'good'},
#  178: {'quality': 'noise'},
#  181: {'quality': 'good'},
#  182: {'quality': 'noise'},
#  183: {'quality': 'good'},
#  184: {'quality': 'noise'},
#  185: {'quality': 'good'},
#  186: {'quality': 'noise'},
#  187: {'quality': 'good'},
#  188: {'quality': 'noise'},
#  189: {'quality': 'good'},
#  190: {'quality': 'noise'},
#  191: {'quality': 'good'},
#  192: {'quality': 'noise'},
#  193: {'quality': 'good'},
#  194: {'quality': 'noise'},
#  199: {'quality': 'good'},
#  200: {'quality': 'noise'},
#  201: {'quality': 'good'},
#  202: {'quality': 'noise'},
#  212: {'quality': 'noise'},
#  222: {'quality': 'good'},
#  223: {'quality': 'noise'},
#  224: {'quality': 'good'},
#  225: {'quality': 'noise'},
#  226: {'quality': 'good'},
#  227: {'quality': 'noise'},
#  228: {'quality': 'good'},
#  229: {'quality': 'noise'},
#  230: {'quality': 'mua'},
#  231: {'quality': 'noise'},
#  232: {'quality': 'good'},
#  233: {'quality': 'noise'},
#  234: {'quality': 'good'},
#  236: {'quality': 'good'},
#  240: {'quality': 'good'},
#  241: {'quality': 'noise'},
#  244: {'quality': 'good'},
#  245: {'quality': 'noise'},
#  254: {'quality': 'good'},
#  255: {'quality': 'noise'},
#  258: {'quality': 'good'},
#  259: {'quality': 'noise'},
#  264: {'quality': 'good'},
#  265: {'quality': 'noise'},
#  274: {'quality': 'good'},
#  275: {'quality': 'noise'},
#  283: {'quality': 'mua', 'chan_group': '0'},
#  285: {'quality': 'good', 'chan_group': '0'},
#  286: {'quality': 'mua', 'chan_group': '0'},
#  287: {'quality': 'good', 'chan_group': '0'},
#  288: {'quality': 'noise', 'chan_group': '0'},
#  300: {'quality': 'mua'},
#  301: {'quality': 'mua'},
#  308: {'quality': 'mua'},
#  310: {'quality': 'mua'},
#  311: {'quality': 'noise'},
#  332: {'quality': 'good', 'chan_group': '0'},
#  335: {'quality': 'good'},
#  336: {'quality': 'noise'},
#  337: {'quality': 'good'},
#  338: {'quality': 'mua', 'chan_group': '0'},
#  348: {'quality': 'good', 'chan_group': '0'},
#  349: {'quality': 'noise', 'chan_group': '0'},
#  354: {'quality': 'mua', 'chan_group': '0'},
#  356: {'quality': 'mua', 'chan_group': '0'},
#  357: {'quality': 'noise', 'chan_group': '0'},
#  360: {'quality': 'good', 'chan_group': '0'},
#  361: {'quality': 'noise', 'chan_group': '0'},
#  362: {'quality': 'noise'},
#  365: {'quality': 'good', 'chan_group': '0'},
#  366: {'quality': 'noise', 'chan_group': '0'},
#  367: {'quality': 'mua', 'chan_group': '0'},
#  369: {'quality': 'mua', 'chan_group': '0'},
#  371: {'quality': 'noise', 'chan_group': '0'},
#  374: {'quality': 'mua', 'chan_group': '0'},
#  375: {'quality': 'mua', 'chan_group': '0'},
#  405: {'quality': 'noise'},
#  406: {'quality': 'mua'},
#  407: {'quality': 'mua'},
#  413: {'quality': 'mua'},
#  417: {'quality': 'mua'},
#  418: {'quality': 'noise'},
#  419: {'quality': 'good'},
#  420: {'quality': 'noise'},
#  421: {'quality': 'good'},
#  423: {'quality': 'mua'},
#  425: {'quality': 'noise'},
#  426: {'quality': 'good'},
#  431: {'quality': 'good'},
#  437: {'quality': 'mua'},
#  441: {'quality': 'noise'},
#  446: {'quality': 'good', 'chan_group': '0'},
#  447: {'quality': 'noise', 'chan_group': '0'},
#  450: {'quality': 'good', 'chan_group': '0'},
#  452: {'quality': 'mua', 'chan_group': '0'},
#  454: {'quality': 'noise', 'chan_group': '0'},
#  455: {'quality': 'good', 'chan_group': '0'},
#  457: {'quality': 'mua', 'chan_group': '0'},
#  462: {'quality': 'mua', 'chan_group': '0'},
#  464: {'quality': 'noise', 'chan_group': '0'},
#  466: {'quality': 'good', 'chan_group': '0'},
#  468: {'quality': 'mua', 'chan_group': '0'},
#  470: {'quality': 'noise', 'chan_group': '0'},
#  471: {'quality': 'mua', 'chan_group': '0'},
#  473: {'quality': 'mua', 'chan_group': '0'},
#  475: {'quality': 'mua', 'chan_group': '0'},
#  477: {'quality': 'mua', 'chan_group': '0'},
#  479: {'quality': 'mua', 'chan_group': '0'},
#  481: {'quality': 'noise', 'chan_group': '0'},
#  482: {'quality': 'noise', 'chan_group': '0'},
#  485: {'quality': 'good', 'chan_group': '0'},
#  486: {'quality': 'noise', 'chan_group': '0'},
#  489: {'quality': 'mua', 'chan_group': '0'},
#  490: {'quality': 'noise', 'chan_group': '0'},
#  495: {'quality': 'good', 'chan_group': '0'},
#  497: {'quality': 'mua', 'chan_group': '0'},
#  499: {'quality': 'noise', 'chan_group': '0'},
#  500: {'quality': 'good', 'chan_group': '0'},
#  501: {'quality': 'noise', 'chan_group': '0'},
#  504: {'quality': 'mua', 'chan_group': '0'},
#  505: {'quality': 'noise', 'chan_group': '0'},
#  508: {'quality': 'good', 'chan_group': '0'},
#  509: {'quality': 'mua', 'chan_group': '0'},
#  510: {'quality': 'mua', 'chan_group': '0'},
#  511: {'quality': 'noise', 'chan_group': '0'},
#  512: {'quality': 'good', 'chan_group': '0'},
#  514: {'quality': 'good', 'chan_group': '0'},
#  516: {'quality': 'mua', 'chan_group': '0'},
#  517: {'quality': 'mua', 'chan_group': '0'},
#  518: {'quality': 'noise', 'chan_group': '0'},
#  519: {'quality': 'good', 'chan_group': '0'},
#  523: {'quality': 'good', 'chan_group': '0'},
#  525: {'quality': 'good', 'chan_group': '0'},
#  527: {'quality': 'noise', 'chan_group': '0'},
#  532: {'quality': 'mua', 'chan_group': '0'},
#  534: {'quality': 'mua', 'chan_group': '0'},
#  536: {'quality': 'noise', 'chan_group': '0'},
#  537: {'quality': 'good', 'chan_group': '0'},
#  539: {'quality': 'good', 'chan_group': '0'},
#  541: {'quality': 'noise', 'chan_group': '0'},
#  542: {'quality': 'good', 'chan_group': '0'},
#  544: {'quality': 'mua', 'chan_group': '0'},
#  546: {'quality': 'noise', 'chan_group': '0'},
#  547: {'quality': 'good', 'chan_group': '0'},
#  553: {'quality': 'mua', 'chan_group': '0'},
#  555: {'quality': 'mua', 'chan_group': '0'},
#  561: {'quality': 'noise', 'chan_group': '0'},
#  563: {'quality': 'noise', 'chan_group': '0'},
#  567: {'quality': 'good', 'chan_group': '0'},
#  568: {'quality': 'mua', 'chan_group': '0'},
#  569: {'quality': 'good', 'chan_group': '0'},
#  570: {'quality': 'noise', 'chan_group': '0'},
#  571: {'quality': 'good', 'chan_group': '0'},
#  572: {'quality': 'noise', 'chan_group': '0'},
#  573: {'quality': 'good', 'chan_group': '0'},
#  574: {'quality': 'mua', 'chan_group': '0'},
#  577: {'quality': 'mua', 'chan_group': '0'},
#  578: {'quality': 'mua', 'chan_group': '0'},
#  581: {'quality': 'good', 'chan_group': '0'},
#  583: {'quality': 'mua', 'chan_group': '0'},
#  585: {'quality': 'noise', 'chan_group': '0'},
#  586: {'quality': 'good', 'chan_group': '0'},
#  587: {'quality': 'noise', 'chan_group': '0'},
#  588: {'quality': 'mua', 'chan_group': '0'},
#  589: {'quality': 'noise', 'chan_group': '0'},
#  596: {'quality': 'mua', 'chan_group': '0'},
#  598: {'quality': 'good', 'chan_group': '0'},
#  600: {'quality': 'good', 'chan_group': '0'},
#  607: {'quality': 'good', 'chan_group': '0'},
#  614: {'quality': 'mua', 'chan_group': '0'},
#  615: {'quality': 'noise', 'chan_group': '0'},
#  618: {'quality': 'mua', 'chan_group': '0'},
#  619: {'quality': 'noise', 'chan_group': '0'},
#  626: {'quality': 'mua', 'chan_group': '0'},
#  628: {'quality': 'mua', 'chan_group': '0'},
#  630: {'quality': 'noise', 'chan_group': '0'},
#  631: {'quality': 'mua', 'chan_group': '0'},
#  632: {'quality': 'noise', 'chan_group': '0'},
#  633: {'quality': 'mua', 'chan_group': '0'},
#  643: {'quality': 'mua', 'chan_group': '0'},
#  647: {'quality': 'good', 'chan_group': '0'},
#  652: {'quality': 'mua', 'chan_group': '0'},
#  654: {'quality': 'noise', 'chan_group': '0'},
#  657: {'quality': 'good', 'chan_group': '0'},
#  658: {'quality': 'noise', 'chan_group': '0'},
#  663: {'quality': 'mua', 'chan_group': '0'},
#  664: {'quality': 'noise', 'chan_group': '0'},
#  666: {'quality': 'noise', 'chan_group': '0'},
#  667: {'quality': 'mua', 'chan_group': '0'},
#  669: {'quality': 'noise', 'chan_group': '0'},
#  670: {'quality': 'mua', 'chan_group': '0'},
#  671: {'quality': 'mua', 'chan_group': '0'},
#  672: {'quality': 'noise', 'chan_group': '0'},
#  674: {'quality': 'noise', 'chan_group': '0'},
#  679: {'quality': 'good', 'chan_group': '0'},
#  680: {'quality': 'mua', 'chan_group': '0'},
#  690: {'quality': 'mua'},
#  692: {'quality': 'mua'},
#  694: {'quality': 'noise'},
#  706: {'quality': 'mua'},
#  708: {'quality': 'noise'}}

# %%
sorting_IC_phy._properties
#(unit_ids=unitIDs, property_name='group')
# Out:
# {0: {'group': 1, 'quality': 'unsorted'},
#  1: {'group': 1, 'quality': 'unsorted'},
#  2: {'group': 1, 'quality': 'unsorted'},
#  3: {'group': 2, 'quality': 'unsorted'},
#  4: {'group': 2, 'quality': 'mua'},
#  5: {'group': 2, 'quality': 'mua'},
#  6: {'group': 2, 'quality': 'mua'},
#  7: {'group': 2, 'quality': 'mua'},
#  8: {'group': 2, 'quality': 'mua'},
#  9: {'group': 2, 'quality': 'unsorted'},
#  10: {'group': 2, 'quality': 'unsorted'},
#  11: {'group': 2, 'quality': 'unsorted'},
#  12: {'group': 3, 'quality': 'unsorted'},
#  13: {'group': 3, 'quality': 'unsorted'},
#  14: {'group': 3, 'quality': 'mua'},
#  15: {'group': 3, 'quality': 'mua'},
#  16: {'group': 3, 'quality': 'good'},
#  17: {'group': 4, 'quality': 'mua'},
#  18: {'group': 4, 'quality': 'mua'},
#  19: {'group': 5, 'quality': 'mua'},
#  20: {'group': 5, 'quality': 'mua'},
#  21: {'group': 5, 'quality': 'mua'},
#  22: {'group': 5, 'quality': 'mua'},
#  23: {'group': 5, 'quality': 'mua'},
#  24: {'group': 6, 'quality': 'unsorted'},
#  25: {'group': 6, 'quality': 'mua'},
#  26: {'group': 6, 'quality': 'mua'},
#  27: {'group': 6, 'quality': 'mua'},
#  28: {'group': 6, 'quality': 'mua'},
#  29: {'group': 6, 'quality': 'mua'},
#  30: {'group': 7, 'quality': 'unsorted'},
#  31: {'group': 7, 'quality': 'unsorted'},
#  32: {'group': 7, 'quality': 'mua'},
#  33: {'group': 7, 'quality': 'mua'},
#  34: {'group': 8, 'quality': 'mua'},
#  35: {'group': 8, 'quality': 'unsorted'},
#  36: {'group': 8, 'quality': 'mua'},
#  37: {'group': 8, 'quality': 'good'},
#  38: {'group': 8, 'quality': 'mua'},
#  39: {'group': 8, 'quality': 'good'},
#  40: {'group': 9, 'quality': 'mua'},
#  41: {'group': 9, 'quality': 'mua'},
#  42: {'group': 9, 'quality': 'unsorted'},
#  43: {'group': 9, 'quality': 'mua'},
#  44: {'group': 10, 'quality': 'unsorted'},
#  45: {'group': 10, 'quality': 'mua'},
#  46: {'group': 10, 'quality': 'mua'},
#  47: {'group': 10, 'quality': 'mua'},
#  48: {'group': 10, 'quality': 'good'},
#  49: {'group': 11, 'quality': 'unsorted'},
#  50: {'group': 11, 'quality': 'unsorted'},
#  51: {'group': 11, 'quality': 'unsorted'},
#  52: {'group': 11, 'quality': 'unsorted'},
#  53: {'group': 11, 'quality': 'mua'},
#  54: {'group': 11, 'quality': 'mua'},
#  55: {'group': 11, 'quality': 'good'},
#  56: {'group': 11, 'quality': 'mua'},
#  57: {'group': 11, 'quality': 'mua'},
#  58: {'group': 11, 'quality': 'mua'},
#  59: {'group': 11, 'quality': 'mua'},
#  60: {'group': 11, 'quality': 'mua'},
#  61: {'group': 12, 'quality': 'mua'},
#  62: {'group': 12, 'quality': 'unsorted'},
#  63: {'group': 12, 'quality': 'mua'},
#  64: {'group': 13, 'quality': 'unsorted'},
#  65: {'group': 13, 'quality': 'unsorted'},
#  66: {'group': 13, 'quality': 'mua'},
#  67: {'group': 13, 'quality': 'mua'},
#  68: {'group': 13, 'quality': 'mua'},
#  69: {'group': 13, 'quality': 'mua'},
#  70: {'group': 14, 'quality': 'mua'},
#  71: {'group': 14, 'quality': 'mua'},
#  72: {'group': 14, 'quality': 'mua'},
#  73: {'group': 15, 'quality': 'unsorted'},
#  74: {'group': 15, 'quality': 'mua'},
#  75: {'group': 16, 'quality': 'mua'},
#  76: {'group': 16, 'quality': 'good'},
#  77: {'group': 16, 'quality': 'good'},
#  78: {'group': 16, 'quality': 'mua'},
#  79: {'group': 17, 'quality': 'unsorted'},
#  80: {'group': 17, 'quality': 'unsorted'},
#  81: {'group': 17, 'quality': 'unsorted'},
#  82: {'group': 17, 'quality': 'mua'},
#  83: {'group': 17, 'quality': 'mua'},
#  84: {'group': 17, 'quality': 'mua'},
#  85: {'group': 18, 'quality': 'mua'},
#  86: {'group': 18, 'quality': 'unsorted'},
#  87: {'group': 18, 'quality': 'mua'},
#  88: {'group': 18, 'quality': 'unsorted'},
#  89: {'group': 18, 'quality': 'mua'},
#  90: {'group': 18, 'quality': 'mua'},
#  91: {'group': 18, 'quality': 'mua'},
#  92: {'group': 18, 'quality': 'mua'},
#  93: {'group': 18, 'quality': 'mua'},
#  94: {'group': 19, 'quality': 'unsorted'},
#  95: {'group': 19, 'quality': 'mua'},
#  96: {'group': 19, 'quality': 'good'},
#  97: {'group': 19, 'quality': 'mua'},
#  98: {'group': 20, 'quality': 'mua'},
#  99: {'group': 20, 'quality': 'unsorted'},
#  100: {'group': 20, 'quality': 'mua'},
#  101: {'group': 20, 'quality': 'mua'},
#  102: {'group': 20, 'quality': 'mua'},
#  103: {'group': 20, 'quality': 'mua'},
#  104: {'group': 20, 'quality': 'mua'},
#  105: {'group': 20, 'quality': 'mua'},
#  106: {'group': 20, 'quality': 'good'},
#  107: {'group': 21, 'quality': 'unsorted'},
#  108: {'group': 21, 'quality': 'unsorted'},
#  109: {'group': 22, 'quality': 'unsorted'},
#  110: {'group': 22, 'quality': 'mua'},
#  111: {'group': 22, 'quality': 'good'},
#  112: {'group': 23, 'quality': 'unsorted'},
#  113: {'group': 23, 'quality': 'unsorted'},
#  114: {'group': 23, 'quality': 'mua'},
#  115: {'group': 23, 'quality': 'mua'},
#  116: {'group': 24, 'quality': 'mua'},
#  117: {'group': 24, 'quality': 'unsorted'},
#  118: {'group': 24, 'quality': 'unsorted'},
#  119: {'group': 24, 'quality': 'mua'},
#  120: {'group': 24, 'quality': 'mua'},
#  121: {'group': 24, 'quality': 'mua'},
#  122: {'group': 25, 'quality': 'mua'},
#  123: {'group': 25, 'quality': 'unsorted'},
#  124: {'group': 25, 'quality': 'good'},
#  125: {'group': 25, 'quality': 'mua'},
#  126: {'group': 25, 'quality': 'mua'},
#  127: {'group': 26, 'quality': 'unsorted'},
#  128: {'group': 26, 'quality': 'mua'},
#  129: {'group': 26, 'quality': 'mua'},
#  130: {'group': 26, 'quality': 'good'},
#  131: {'group': 27, 'quality': 'mua'},
#  132: {'group': 27, 'quality': 'unsorted'},
#  133: {'group': 27, 'quality': 'mua'},
#  134: {'group': 28, 'quality': 'unsorted'},
#  135: {'group': 28, 'quality': 'unsorted'},
#  136: {'group': 28, 'quality': 'good'},
#  137: {'group': 28, 'quality': 'unsorted'},
#  138: {'group': 28, 'quality': 'mua'},
#  139: {'group': 28, 'quality': 'mua'},
#  140: {'group': 28, 'quality': 'mua'},
#  141: {'group': 28, 'quality': 'mua'},
#  142: {'group': 28, 'quality': 'mua'},
#  143: {'group': 28, 'quality': 'mua'},
#  144: {'group': 28, 'quality': 'mua'},
#  145: {'group': 28, 'quality': 'mua'},
#  146: {'group': 28, 'quality': 'mua'},
#  147: {'group': 29, 'quality': 'unsorted'},
#  148: {'group': 29, 'quality': 'unsorted'},
#  149: {'group': 29, 'quality': 'unsorted'},
#  150: {'group': 29, 'quality': 'unsorted'},
#  151: {'group': 29, 'quality': 'unsorted'},
#  152: {'group': 29, 'quality': 'unsorted'},
#  153: {'group': 29, 'quality': 'unsorted'},
#  154: {'group': 29, 'quality': 'unsorted'},
#  155: {'group': 29, 'quality': 'mua'},
#  156: {'group': 29, 'quality': 'good'},
#  157: {'group': 29, 'quality': 'mua'},
#  158: {'group': 29, 'quality': 'mua'},
#  159: {'group': 29, 'quality': 'mua'},
#  160: {'group': 30, 'quality': 'unsorted'},
#  161: {'group': 30, 'quality': 'mua'},
#  162: {'group': 30, 'quality': 'mua'},
#  163: {'group': 30, 'quality': 'good'},
#  164: {'group': 30, 'quality': 'mua'},
#  165: {'group': 30, 'quality': 'mua'},
#  166: {'group': 31, 'quality': 'unsorted'},
#  167: {'group': 31, 'quality': 'unsorted'},
#  168: {'group': 31, 'quality': 'mua'},
#  169: {'group': 31, 'quality': 'good'},
#  170: {'group': 32, 'quality': 'unsorted'},
#  171: {'group': 33, 'quality': 'unsorted'},
#  172: {'group': 33, 'quality': 'unsorted'},
#  173: {'group': 35, 'quality': 'unsorted'},
#  174: {'group': 35, 'quality': 'unsorted'},
#  175: {'group': 35, 'quality': 'unsorted'},
#  176: {'group': 36, 'quality': 'unsorted'},
#  177: {'group': 36, 'quality': 'unsorted'},
#  178: {'group': 36, 'quality': 'mua'},
#  179: {'group': 36, 'quality': 'mua'},
#  180: {'group': 37, 'quality': 'unsorted'},
#  181: {'group': 37, 'quality': 'mua'},
#  182: {'group': 37, 'quality': 'good'},
#  183: {'group': 38, 'quality': 'unsorted'},
#  184: {'group': 38, 'quality': 'unsorted'},
#  185: {'group': 38, 'quality': 'mua'},
#  186: {'group': 38, 'quality': 'unsorted'},
#  187: {'group': 38, 'quality': 'mua'},
#  188: {'group': 39, 'quality': 'mua'},
#  189: {'group': 39, 'quality': 'unsorted'},
#  190: {'group': 40, 'quality': 'mua'},
#  191: {'group': 40, 'quality': 'unsorted'},
#  192: {'group': 41, 'quality': 'unsorted'},
#  193: {'group': 41, 'quality': 'unsorted'},
#  194: {'group': 41, 'quality': 'good'},
#  195: {'group': 42, 'quality': 'unsorted'},
#  196: {'group': 42, 'quality': 'unsorted'},
#  197: {'group': 42, 'quality': 'unsorted'},
#  198: {'group': 42, 'quality': 'mua'},
#  199: {'group': 42, 'quality': 'unsorted'},
#  200: {'group': 42, 'quality': 'good'},
#  201: {'group': 42, 'quality': 'mua'},
#  202: {'group': 43, 'quality': 'unsorted'},
#  203: {'group': 43, 'quality': 'unsorted'},
#  204: {'group': 43, 'quality': 'mua'},
#  205: {'group': 43, 'quality': 'mua'},
#  206: {'group': 43, 'quality': 'mua'},
#  207: {'group': 43, 'quality': 'mua'},
#  208: {'group': 44, 'quality': 'unsorted'},
#  209: {'group': 44, 'quality': 'unsorted'},
#  210: {'group': 44, 'quality': 'unsorted'},
#  211: {'group': 44, 'quality': 'mua'},
#  212: {'group': 45, 'quality': 'unsorted'},
#  213: {'group': 45, 'quality': 'mua'},
#  214: {'group': 45, 'quality': 'mua'},
#  215: {'group': 45, 'quality': 'mua'},
#  216: {'group': 45, 'quality': 'mua'},
#  217: {'group': 45, 'quality': 'mua'},
#  218: {'group': 46, 'quality': 'unsorted'},
#  219: {'group': 46, 'quality': 'unsorted'},
#  220: {'group': 47, 'quality': 'mua'},
#  221: {'group': 47, 'quality': 'mua'},
#  222: {'group': 47, 'quality': 'unsorted'},
#  223: {'group': 48, 'quality': 'unsorted'},
#  224: {'group': 48, 'quality': 'unsorted'},
#  225: {'group': 49, 'quality': 'mua'},
#  226: {'group': 49, 'quality': 'unsorted'},
#  227: {'group': 49, 'quality': 'mua'},
#  228: {'group': 49, 'quality': 'mua'},
#  229: {'group': 50, 'quality': 'unsorted'},
#  230: {'group': 50, 'quality': 'mua'},
#  231: {'group': 51, 'quality': 'unsorted'},
#  232: {'group': 51, 'quality': 'good'},
#  233: {'group': 52, 'quality': 'unsorted'},
#  234: {'group': 52, 'quality': 'unsorted'},
#  235: {'group': 53, 'quality': 'unsorted'},
#  236: {'group': 53, 'quality': 'mua'},
#  237: {'group': 53, 'quality': 'good'},
#  238: {'group': 53, 'quality': 'mua'},
#  239: {'group': 53, 'quality': 'mua'},
#  240: {'group': 54, 'quality': 'unsorted'},
#  241: {'group': 54, 'quality': 'unsorted'},
#  242: {'group': 55, 'quality': 'mua'},
#  243: {'group': 55, 'quality': 'unsorted'},
#  244: {'group': 55, 'quality': 'unsorted'},
#  245: {'group': 56, 'quality': 'unsorted'},
#  246: {'group': 56, 'quality': 'unsorted'},
#  247: {'group': 57, 'quality': 'unsorted'},
#  248: {'group': 57, 'quality': 'mua'},
#  249: {'group': 57, 'quality': 'unsorted'},
#  250: {'group': 57, 'quality': 'mua'},
#  251: {'group': 57, 'quality': 'mua'},
#  252: {'group': 57, 'quality': 'mua'},
#  253: {'group': 58, 'quality': 'unsorted'},
#  254: {'group': 58, 'quality': 'good'},
#  255: {'group': 59, 'quality': 'unsorted'},
#  256: {'group': 59, 'quality': 'unsorted'},
#  257: {'group': 59, 'quality': 'good'},
#  258: {'group': 60, 'quality': 'unsorted'},
#  259: {'group': 60, 'quality': 'good'},
#  260: {'group': 60, 'quality': 'good'},
#  261: {'group': 61, 'quality': 'unsorted'},
#  262: {'group': 61, 'quality': 'unsorted'},
#  263: {'group': 61, 'quality': 'good'},
#  264: {'group': 62, 'quality': 'unsorted'},
#  265: {'group': 62, 'quality': 'unsorted'},
#  266: {'group': 62, 'quality': 'mua'},
#  267: {'group': 63, 'quality': 'unsorted'},
#  268: {'group': 63, 'quality': 'unsorted'},
#  269: {'group': 63, 'quality': 'mua'},
#  270: {'group': 64, 'quality': 'unsorted'},
#  271: {'group': 64, 'quality': 'mua'},
#  272: {'group': 64, 'quality': 'mua'},
#  273: {'group': 65, 'quality': 'unsorted'},
#  274: {'group': 65, 'quality': 'good'},
#  275: {'group': 66, 'quality': 'mua'},
#  276: {'group': 66, 'quality': 'mua'},
#  277: {'group': 66, 'quality': 'unsorted'},
#  278: {'group': 66, 'quality': 'mua'},
#  279: {'group': 66, 'quality': 'mua'},
#  280: {'group': 68, 'quality': 'unsorted'},
#  281: {'group': 68, 'quality': 'mua'},
#  282: {'group': 68, 'quality': 'good'},
#  283: {'group': 68, 'quality': 'good'},
#  284: {'group': 68, 'quality': 'mua'},
#  285: {'group': 68, 'quality': 'mua'},
#  286: {'group': 68, 'quality': 'mua'},
#  287: {'group': 69, 'quality': 'unsorted'},
#  288: {'group': 69, 'quality': 'mua'},
#  289: {'group': 69, 'quality': 'mua'},
#  290: {'group': 70, 'quality': 'unsorted'},
#  291: {'group': 70, 'quality': 'mua'},
#  292: {'group': 70, 'quality': 'mua'},
#  293: {'group': 70, 'quality': 'mua'},
#  294: {'group': 70, 'quality': 'good'},
#  295: {'group': 70, 'quality': 'mua'},
#  296: {'group': 71, 'quality': 'unsorted'},
#  297: {'group': 71, 'quality': 'unsorted'},
#  298: {'group': 71, 'quality': 'unsorted'},
#  299: {'group': 71, 'quality': 'mua'},
#  300: {'group': 71, 'quality': 'mua'},
#  301: {'group': 72, 'quality': 'unsorted'},
#  302: {'group': 72, 'quality': 'unsorted'},
#  303: {'group': 72, 'quality': 'unsorted'},
#  304: {'group': 72, 'quality': 'unsorted'},
#  305: {'group': 72, 'quality': 'good'},
#  306: {'group': 73, 'quality': 'unsorted'},
#  307: {'group': 73, 'quality': 'mua'},
#  308: {'group': 73, 'quality': 'unsorted'},
#  309: {'group': 73, 'quality': 'good'},
#  310: {'group': 73, 'quality': 'good'},
#  311: {'group': 74, 'quality': 'unsorted'},
#  312: {'group': 74, 'quality': 'mua'},
#  313: {'group': 74, 'quality': 'good'},
#  314: {'group': 75, 'quality': 'unsorted'},
#  315: {'group': 75, 'quality': 'mua'},
#  316: {'group': 75, 'quality': 'mua'},
#  317: {'group': 76, 'quality': 'unsorted'},
#  318: {'group': 76, 'quality': 'unsorted'},
#  319: {'group': 76, 'quality': 'mua'},
#  320: {'group': 76, 'quality': 'mua'},
#  321: {'group': 76, 'quality': 'mua'},
#  322: {'group': 77, 'quality': 'mua'},
#  323: {'group': 77, 'quality': 'unsorted'},
#  324: {'group': 77, 'quality': 'unsorted'},
#  325: {'group': 78, 'quality': 'unsorted'},
#  326: {'group': 78, 'quality': 'mua'},
#  327: {'group': 78, 'quality': 'mua'},
#  328: {'group': 79, 'quality': 'unsorted'},
#  329: {'group': 79, 'quality': 'mua'},
#  330: {'group': 80, 'quality': 'unsorted'},
#  331: {'group': 80, 'quality': 'unsorted'},
#  332: {'group': 80, 'quality': 'unsorted'},
#  333: {'group': 80, 'quality': 'good'},
#  334: {'group': 81, 'quality': 'unsorted'},
#  335: {'group': 81, 'quality': 'mua'},
#  336: {'group': 81, 'quality': 'mua'},
#  337: {'group': 81, 'quality': 'mua'},
#  338: {'group': 82, 'quality': 'unsorted'},
#  339: {'group': 82, 'quality': 'mua'},
#  340: {'group': 82, 'quality': 'good'},
#  341: {'group': 83, 'quality': 'unsorted'},
#  342: {'group': 83, 'quality': 'unsorted'},
#  343: {'group': 83, 'quality': 'unsorted'},
#  344: {'group': 83, 'quality': 'unsorted'},
#  345: {'group': 84, 'quality': 'unsorted'},
#  346: {'group': 84, 'quality': 'mua'},
#  347: {'group': 84, 'quality': 'good'},
#  348: {'group': 84, 'quality': 'mua'},
#  349: {'group': 84, 'quality': 'mua'},
#  350: {'group': 85, 'quality': 'unsorted'},
#  351: {'group': 85, 'quality': 'mua'},
#  352: {'group': 85, 'quality': 'mua'},
#  353: {'group': 86, 'quality': 'unsorted'},
#  354: {'group': 86, 'quality': 'mua'},
#  355: {'group': 86, 'quality': 'good'},
#  356: {'group': 86, 'quality': 'good'},
#  357: {'group': 87, 'quality': 'unsorted'},
#  358: {'group': 87, 'quality': 'unsorted'},
#  359: {'group': 87, 'quality': 'unsorted'},
#  360: {'group': 87, 'quality': 'mua'},
#  361: {'group': 87, 'quality': 'mua'},
#  362: {'group': 87, 'quality': 'mua'},
#  363: {'group': 87, 'quality': 'mua'},
#  364: {'group': 87, 'quality': 'mua'},
#  365: {'group': 88, 'quality': 'unsorted'},
#  366: {'group': 88, 'quality': 'good'},
#  367: {'group': 88, 'quality': 'mua'},
#  368: {'group': 89, 'quality': 'unsorted'},
#  369: {'group': 89, 'quality': 'good'},
#  370: {'group': 89, 'quality': 'good'},
#  371: {'group': 90, 'quality': 'unsorted'},
#  372: {'group': 90, 'quality': 'good'},
#  373: {'group': 91, 'quality': 'unsorted'},
#  374: {'group': 91, 'quality': 'unsorted'},
#  375: {'group': 91, 'quality': 'mua'},
#  376: {'group': 91, 'quality': 'good'},
#  377: {'group': 92, 'quality': 'unsorted'},
#  378: {'group': 92, 'quality': 'good'},
#  379: {'group': 93, 'quality': 'unsorted'},
#  380: {'group': 93, 'quality': 'unsorted'},
#  381: {'group': 93, 'quality': 'mua'},
#  382: {'group': 93, 'quality': 'good'},
#  383: {'group': 93, 'quality': 'mua'},
#  384: {'group': 94, 'quality': 'unsorted'},
#  385: {'group': 94, 'quality': 'unsorted'},
#  386: {'group': 94, 'quality': 'unsorted'},
#  387: {'group': 95, 'quality': 'unsorted'},
#  388: {'group': 95, 'quality': 'unsorted'},
#  389: {'group': 95, 'quality': 'unsorted'},
#  390: {'group': 96, 'quality': 'unsorted'},
#  391: {'group': 96, 'quality': 'unsorted'},
#  392: {'group': 96, 'quality': 'unsorted'}}

# %%
# Append the sorting data to the NWB file by using setting the overwrite argument to False
# import phy curation

#sorting_IC_phy = se.PhySortingExtractor('/scratch/midway3/daltonm/phy_sorting_by_paul/phy_IC/')
#sorting_IC_phy = se.PhySortingExtractor('/scratch/midway3/daltonm/phy_sorting_by_paul/phy_IC/', exclude_cluster_groups='noise')
#sorting_IC_phy = se.PhySortingExtractor('/project2/nicho/dalton/phy_sorting_by_paul/phy_IC/', exclude_cluster_groups=['noise', 'mua'])
sorting_IC_phy = se.PhySortingExtractor('/project/nicho/data/marmosets/electrophys_data_for_processing/TY20210211_freeAndMoths/phy_TDC/', exclude_cluster_groups=['noise', 'mua'])

#nwb_file = '/project/nicho/data/marmosets/electrophys_data_for_processing/TY20221024_testbattery/TY20221024_testbattery_001_NWBTEST_only_neural_converters_NEWWWWW.nwb'
#nwb_file = '/project2/nicho/marmoset_tempStorage/electrophys_data_for_processing/TY20221024_testbattery/TY20221024_testbattery_001_PHY.nwb'
nwb_file = '/project/nicho/data/marmosets/electrophys_data_for_processing/TY20210211_freeAndMoths/TY20210211_freeAndMoths-003_PHYTEST.nwb'

unitIDs = sorting_IC_phy.get_unit_ids()
#sorting_IC_phy.set_units_property(unit_ids=unitIDs, 
#                                  property_name='channel_index', 
#                                  values=sorting_IC_phy.get_units_property(unit_ids=unitIDs, property_name='group'))
#se.NwbSortingExtractor.write_sorting(sorting_IC_phy, nwb_file, overwrite=False)

# %%
sorting_IC_phy.set_units_property(unit_ids=unitIDs, 
                                  property_name='channel_index', 
                                  values=sorting_IC_phy.get_units_property(unit_ids=unitIDs, property_name='group'))

# %% [markdown]
# # Extra cells that might be helpful

# %% [markdown]
# If export to phy crashes, try running these next three cells first, then retry export to phy.

# %%
# get waveforms for chosen sorter
st.postprocessing.get_unit_waveforms(recording_cache, sorting_IC_cache, 
                                     ms_before=0.5, 
                                     ms_after=1, 
                                     compute_property_from_recording=True, 
                                     n_jobs=10, 
                                     max_spikes_per_unit=None, 
                                     memmap=True, 
                                     save_property_or_features=True, 
                                     recompute_info=True, 
                                     verbose=True)

# %%
# get amplitudes for chosen sorter
st.postprocessing.get_unit_amplitudes(recording_cache, sorting_IC_cache, 
                                      ms_before=0.5, 
                                      ms_after=1, 
                                      max_spikes_per_unit=None, 
                                      memmap=True, 
                                      save_property_or_features=True, 
                                      n_jobs=10, 
                                      verbose=True)

# %%
# unit templates
st.postprocessing.get_unit_templates(recording_cache, sorting_IC_cache, 
                                     ms_before=0.5, 
                                     ms_after=1, 
                                     max_spikes_per_unit=None, 
                                     memmap=True, 
                                     save_property_or_feature=True, 
                                     n_jobs=10, 
                                     verbose=True)

# %% [markdown]
# In case the isi violations throws an error, try running these cells first

# %%
duration = recording_cache.get_num_frames()
isi_violations = st.validation.compute_isi_violations(sorting_IC, duration_in_frames=duration)
print('ISI violations:', isi_violations)

snrs = st.validation.compute_snrs(sorting_IC, recording_cache)
print('SNRs:', snrs)
